# %%
import re

def split_sentences_with_punctuation(text):
    # Define regex pattern to match sentence-ending punctuation
    pattern = r'([.!?]+)'

    # Use regex to split text into sentences based on the pattern
    sentences = re.split(pattern, text)

    # Combine sentences with their respective punctuation marks
    combined_sentences = []
    i = 0
    while i < len(sentences) - 1:
        sentence = sentences[i].strip()
        punctuation = sentences[i + 1] if i + 1 < len(sentences) else ''
        combined_sentence = sentence + punctuation
        combined_sentences.append(combined_sentence)
        i += 2

    return combined_sentences

# %%
# Set to True in order to use the pyttsx3 model for the voice assistant, fast inference but sounds like a robot
pytts = True

# %%
import os
import torch
import torchaudio
from TTS.api import TTS
from TTS.tts.configs.xtts_config import XttsConfig
from TTS.tts.models.xtts import Xtts

print("Loading model...")
config = XttsConfig()
config.load_json("xtts/config.json")
model = Xtts.init_from_config(config)
model.load_checkpoint(config, checkpoint_dir='xtts/')

print("Computing speaker latents...")
gpt_cond_latent, speaker_embedding = model.get_conditioning_latents(audio_path=["reference_audio/IAmLegend_ep6 - 017.wav"])
# Out:
# Loading model...
# Computing speaker latents...

# %% [markdown]
# ## Inference on the entire text
#
# CPU times: user 15 µs, sys: 14 µs, total: 29 µs
# Wall time: 3.1 µs

# %%
from IPython.display import Audio

print("Inference...")
out = model.inference(
    "It took me quite a long time to develop a voice and now that I have it I am not going to be silent.",
    "en",
    gpt_cond_latent,
    speaker_embedding,
    temperature=0.7, 
)

# Instead of saving to file, directly play the audio
display(Audio(data=out["wav"], rate=24000, autoplay=True))
# %time

# %% [markdown]
# ## Splitting text to chunks per the documentation
#
# Quickly get the audio but broken up between play and pause

# %%
from IPython.display import display, Audio
import time

print("Inference...")
t0 = time.time()
chunks = model.inference_stream(
    "It took me quite a long time to develop a voice and now that I have it I am not going to be silent.",
    "en",
    gpt_cond_latent,
    speaker_embedding
)

print(f"Time to first chunk: {time.time() - t0}")

# Iterate over chunks and play each one
for i, chunk in enumerate(chunks):
    print(f"Playing chunk {i} of audio length {chunk.shape[-1]}")
    display(Audio(data=chunk.squeeze().cpu().numpy(), rate=24000, autoplay=True))

# %% [markdown]
# ## Attempt at overlapping the audio to remove the pause between segments
#
# This doesnt work because it still takes too long for segments to load between so now i have overlap and a pause

# %%
def overlap_and_add(prev_chunk, new_chunk, overlap_length):
    """Overlap and add function to combine two audio chunks with overlap."""
    if overlap_length <= 0:
        return new_chunk
    else:
        # Calculate overlap region
        overlap = prev_chunk[-overlap_length:]
        new_part = new_chunk[:overlap_length]
        # Compute weighted sum for smooth transition
        overlap_weight = torch.linspace(0.25, 0.0, overlap_length, device=overlap.device)
        combined_part = (overlap * overlap_weight) + (new_part * (1 - overlap_weight))
        # Concatenate remaining parts of the new chunk
        combined_chunk = torch.cat([prev_chunk[:-overlap_length], combined_part, new_chunk[overlap_length:]], dim=0)
        return combined_chunk

# %%
from IPython.display import display, Audio
import time

print("Inference...")
t0 = time.time()
chunks = model.inference_stream(
    "It took me quite a long time to develop a voice and now that I have it I am not going to be silent.",
    "en",
    gpt_cond_latent,
    speaker_embedding
)

print(f"Time to first chunk: {time.time() - t0}")

# Initialize the previous chunk to None
prev_chunk = None

# Set the desired overlap length (in samples)
overlap_length = 1  # Adjust this value based on your preference

# Iterate over chunks and play each one with overlap-and-add
for i, chunk in enumerate(chunks):
    # if i > 0:
        print(f"Playing chunk {i} of audio length {chunk.shape[-1]}")
            
        if prev_chunk is not None:
                # Apply overlap-and-add to smooth transitions
            combined_chunk = overlap_and_add(prev_chunk, chunk, overlap_length)
        else:
            combined_chunk = chunk
            
            # Display and play the combined chunk
        display(Audio(data=combined_chunk.squeeze().cpu().numpy(), rate=24000, autoplay=True))
            
            # Update prev_chunk to current chunk for the next iteration
        prev_chunk = chunk

# %% [markdown]
# ### Tried lots and lots of times to adjust how the overlap works with no luck
#
# chalkig up the overlap idea to a fail

# %%
from IPython.display import display, Audio
import time

print("Inference...")
t0 = time.time()
chunks = model.inference_stream(
    "It took me quite a long time to develop a voice and now that I have it I am not going to be silent.",
    "en",
    gpt_cond_latent,
    speaker_embedding
)

print(f"Time to first chunk: {time.time() - t0}")

# Initialize the previous chunk to None
prev_chunk = None

# Set the desired overlap length (in samples)
overlap_length = 1  # Adjust this value based on your preference

# Iterate over chunks and play each one with overlap-and-add
for i, chunk in enumerate(chunks):
    if i > 0:  # Skip playing chunk 0
        print(f"Playing chunk {i} of audio length {chunk.shape[-1]}")
        
        if prev_chunk is not None:
            # Apply overlap-and-add to smooth transitions
            combined_chunk = overlap_and_add(prev_chunk, chunk, overlap_length)
        else:
            combined_chunk = chunk
        
        # Display and play the combined chunk
        display(Audio(data=combined_chunk.squeeze().cpu().numpy(), rate=24000, autoplay=True))
        
        # Update prev_chunk to current chunk for the next iteration
        prev_chunk = chunk

# %% [markdown]
# ## Had an idea on breaking large text into chunks so that the model could pronounce each chunk then put them back together (since there is a 250 character minimum)
#
# Doesnt really help with the problem i'm trying to solve but is a cool feature if i want to make an app that can build audio books from any chunk of text

# %%
import time
import torch
import torchaudio
import sounddevice as sd
import numpy as np
import nltk
from nltk.tokenize import sent_tokenize
from TTS.tts.configs.xtts_config import XttsConfig
from TTS.tts.models.xtts import Xtts

# Download NLTK sentence tokenizer data
nltk.download('punkt')

print("Inference...")
t0 = time.time()

# Input text to be synthesized
input_text = "It took me quite a long time to develop a voice. Now that I have it, I am not going to be silent."

# Tokenize input text into sentences
sentences = sent_tokenize(input_text)

# Initialize an empty list to collect sentence audio waveforms
sentence_audio_waveforms = []

# Iterate over each sentence and synthesize audio
for i, sentence in enumerate(sentences):
    print(f"Synthesizing sentence {i + 1}: {sentence}")

    # Synthesize audio for the current sentence
    chunks = model.inference_stream(sentence, "en", gpt_cond_latent, speaker_embedding)

    # Collect all audio chunks for the current sentence
    sentence_audio_chunks = []
    for chunk in chunks:
        audio_numpy = chunk.squeeze().numpy()
        sentence_audio_chunks.append(audio_numpy)

    # Concatenate all audio chunks into a single waveform for the sentence
    sentence_audio_waveform = np.concatenate(sentence_audio_chunks)

    # Append the sentence audio waveform to the list of sentence waveforms
    sentence_audio_waveforms.append(sentence_audio_waveform)

# Concatenate all sentence audio waveforms into a single continuous waveform
audio_waveform = np.concatenate(sentence_audio_waveforms)

# Set the sample rate for playback
sample_rate = 24000

# Play the entire concatenated audio waveform in real-time
sd.play(audio_waveform, sample_rate)

# Wait for the playback to finish before exiting
sd.wait()

# Calculate total time taken for inference and synthesis
# %time
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/darylroberts/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Inference...
# Synthesizing sentence 1: It took me quite a long time to develop a voice.
# Synthesizing sentence 2: Now that I have it, I am not going to be silent.
# CPU times: user 3 µs, sys: 2 µs, total: 5 µs
# Wall time: 125 µs

# %% [markdown]
# ## Mix of splitting on sentence and splitting audio chunks
#
# I thought maybe the pause between audio chunks could sound better/make more sense if it was between sentences
#
# It didnt work, the pause between sentences is still pretty large so its awkwardly pausing between sentences for too long

# %%
text = """By using this approach, each sentence in the output will include its corresponding sentence-ending punctuation. The loop in split_sentences_with_punctuation() combines each sentence with its captured punctuation mark to create the final list of combined sentences.

Feel free to adjust the regex pattern or modify the processing logic based on your specific requirements and text data. This approach provides more control over how punctuation marks are handled when splitting text into sentences using regex.

If you have any further questions or need additional clarification, please let me know! I'm here to help."""

# Split text into sentences with preserved punctuation using regex
sentences = split_sentences_with_punctuation(text)

# Display the split sentences with punctuation
for idx, sentence in enumerate(sentences):
    print(f"Sentence {idx + 1}: {sentence}")
# Out:
# Sentence 1: By using this approach, each sentence in the output will include its corresponding sentence-ending punctuation.
# Sentence 2: The loop in split_sentences_with_punctuation() combines each sentence with its captured punctuation mark to create the final list of combined sentences.
# Sentence 3: Feel free to adjust the regex pattern or modify the processing logic based on your specific requirements and text data.
# Sentence 4: This approach provides more control over how punctuation marks are handled when splitting text into sentences using regex.
# Sentence 5: If you have any further questions or need additional clarification, please let me know!
# Sentence 6: I'm here to help.

# %%
from IPython.display import Audio
for sentence in sentences:
    print("Inference...")
    out = model.inference(
        sentence,
        "en",
        gpt_cond_latent,
        speaker_embedding,
        temperature=0.3,
    )
    
    # Instead of saving to file, directly play the audio
    display(Audio(data=out["wav"], rate=24000, autoplay=True))

##NOTE THE "I'm here to help" sentence plays before the previous sentence is over

# %% [markdown]
# ## Tried seeing if shorter sentences in the text block would make it faster to load between sentences so there was no pause
#
# this didnt work

# %%
text2 = """Sir, I observed a dog today.
Playful eyes, wagging tail.
Curious sniffs, joyful barks.
Exploring the world around.
Leaping through open fields.
Chasing butterflies, endless joy.
Gentle nuzzles, loving heart.
Loyal companion, true friend.
Always by your side, unwavering.
Moments shared, memories cherished.
In every wag, pure happiness.
A dog's life, full of wonder.
"""

sentences2 = split_sentences_with_punctuation(text2)

for idx, sentence in enumerate(sentences2):
    print(f"Sentence {idx + 1}: {sentence}")
# Out:
# Sentence 1: Sir, I observed a dog today.
# Sentence 2: Playful eyes, wagging tail.
# Sentence 3: Curious sniffs, joyful barks.
# Sentence 4: Exploring the world around.
# Sentence 5: Leaping through open fields.
# Sentence 6: Chasing butterflies, endless joy.
# Sentence 7: Gentle nuzzles, loving heart.
# Sentence 8: Loyal companion, true friend.
# Sentence 9: Always by your side, unwavering.
# Sentence 10: Moments shared, memories cherished.
# Sentence 11: In every wag, pure happiness.
# Sentence 12: A dog's life, full of wonder.

# %%
from IPython.display import Audio
for sentence in sentences2:
    print("Inference...")
    out = model.inference(
        sentence,
        "en",
        gpt_cond_latent,
        speaker_embedding,
        temperature=0.3,
    )
    
    # Instead of saving to file, directly play the audio
    display(Audio(data=out["wav"], rate=24000, autoplay=True))

# %% [markdown]
# ## A Much faster text to speech option but its too roboty....
#
# #### Note: I changed the rate of speech from 200 so it would talk a tad slower and experimentented with alot of different voices from the block below and found that 'Tessa' was the best option...

# %%
import pyttsx3
engine = pyttsx3.init()
engine.setProperty('rate',170)
engine.setProperty('voice', 'com.apple.voice.compact.en-ZA.Tessa')
engine.say('It took me quite a long time to develop a voice. Now that I have it, I am not going to be silent.')
engine.runAndWait()

# %%
voices = engine.getProperty('voices')

# Print information about each voice
for i,voice in enumerate(voices):
    print(f"Voice {i}:")
    print(" - Name:", voice.name)
    print(" - ID:", voice.id)
    print(" - Languages:", voice.languages)
    print(" - Gender:", voice.gender)
    print(" - Age:", voice.age)
    # print(" - Vendor:", voice.vendor)
    print()
# Out:
# Voice 0:
#  - Name: Albert
#  - ID: com.apple.speech.synthesis.voice.Albert
#  - Languages: ['en_US']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 1:
#  - Name: Alice
#  - ID: com.apple.voice.compact.it-IT.Alice
#  - Languages: ['it_IT']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 2:
#  - Name: Alva
#  - ID: com.apple.voice.compact.sv-SE.Alva
#  - Languages: ['sv_SE']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 3:
#  - Name: Amélie
#  - ID: com.apple.voice.compact.fr-CA.Amelie
#  - Languages: ['fr_CA']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 4:
#  - Name: Amira
#  - ID: com.apple.voice.compact.ms-MY.Amira
#  - Languages: ['ms_MY']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 5:
#  - Name: Anna
#  - ID: com.apple.voice.compact.de-DE.Anna
#  - Languages: ['de_DE']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 6:
#  - Name: Bad News
#  - ID: com.apple.speech.synthesis.voice.BadNews
#  - Languages: ['en_US']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 7:
#  - Name: Bahh
#  - ID: com.apple.speech.synthesis.voice.Bahh
#  - Languages: ['en_US']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 8:
#  - Name: Bells
#  - ID: com.apple.speech.synthesis.voice.Bells
#  - Languages: ['en_US']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 9:
#  - Name: Boing
#  - ID: com.apple.speech.synthesis.voice.Boing
#  - Languages: ['en_US']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 10:
#  - Name: Bubbles
#  - ID: com.apple.speech.synthesis.voice.Bubbles
#  - Languages: ['en_US']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 11:
#  - Name: Carmit
#  - ID: com.apple.voice.compact.he-IL.Carmit
#  - Languages: ['he_IL']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 12:
#  - Name: Cellos
#  - ID: com.apple.speech.synthesis.voice.Cellos
#  - Languages: ['en_US']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 13:
#  - Name: Damayanti
#  - ID: com.apple.voice.compact.id-ID.Damayanti
#  - Languages: ['id_ID']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 14:
#  - Name: Daniel
#  - ID: com.apple.voice.compact.en-GB.Daniel
#  - Languages: ['en_GB']
#  - Gender: VoiceGenderMale
#  - Age: None
#
# Voice 15:
#  - Name: Daria
#  - ID: com.apple.voice.compact.bg-BG.Daria
#  - Languages: ['bg_BG']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 16:
#  - Name: Wobble
#  - ID: com.apple.speech.synthesis.voice.Deranged
#  - Languages: ['en_US']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 17:
#  - Name: Eddy (German (Germany))
#  - ID: com.apple.eloquence.de-DE.Eddy
#  - Languages: ['de_DE']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 18:
#  - Name: Eddy (English (UK))
#  - ID: com.apple.eloquence.en-GB.Eddy
#  - Languages: ['en_GB']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 19:
#  - Name: Eddy (English (US))
#  - ID: com.apple.eloquence.en-US.Eddy
#  - Languages: ['en_US']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 20:
#  - Name: Eddy (Spanish (Spain))
#  - ID: com.apple.eloquence.es-ES.Eddy
#  - Languages: ['es_ES']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 21:
#  - Name: Eddy (Spanish (Mexico))
#  - ID: com.apple.eloquence.es-MX.Eddy
#  - Languages: ['es_MX']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 22:
#  - Name: Eddy (Finnish (Finland))
#  - ID: com.apple.eloquence.fi-FI.Eddy
#  - Languages: ['fi_FI']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 23:
#  - Name: Eddy (French (Canada))
#  - ID: com.apple.eloquence.fr-CA.Eddy
#  - Languages: ['fr_CA']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 24:
#  - Name: Eddy (French (France))
#  - ID: com.apple.eloquence.fr-FR.Eddy
#  - Languages: ['fr_FR']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 25:
#  - Name: Eddy (Italian (Italy))
#  - ID: com.apple.eloquence.it-IT.Eddy
#  - Languages: ['it_IT']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 26:
#  - Name: Eddy (Portuguese (Brazil))
#  - ID: com.apple.eloquence.pt-BR.Eddy
#  - Languages: ['pt_BR']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 27:
#  - Name: Ellen
#  - ID: com.apple.voice.compact.nl-BE.Ellen
#  - Languages: ['nl_BE']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 28:
#  - Name: Flo (German (Germany))
#  - ID: com.apple.eloquence.de-DE.Flo
#  - Languages: ['de_DE']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 29:
#  - Name: Flo (English (UK))
#  - ID: com.apple.eloquence.en-GB.Flo
#  - Languages: ['en_GB']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 30:
#  - Name: Flo (English (US))
#  - ID: com.apple.eloquence.en-US.Flo
#  - Languages: ['en_US']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 31:
#  - Name: Flo (Spanish (Spain))
#  - ID: com.apple.eloquence.es-ES.Flo
#  - Languages: ['es_ES']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 32:
#  - Name: Flo (Spanish (Mexico))
#  - ID: com.apple.eloquence.es-MX.Flo
#  - Languages: ['es_MX']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 33:
#  - Name: Flo (Finnish (Finland))
#  - ID: com.apple.eloquence.fi-FI.Flo
#  - Languages: ['fi_FI']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 34:
#  - Name: Flo (French (Canada))
#  - ID: com.apple.eloquence.fr-CA.Flo
#  - Languages: ['fr_CA']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 35:
#  - Name: Flo (French (France))
#  - ID: com.apple.eloquence.fr-FR.Flo
#  - Languages: ['fr_FR']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 36:
#  - Name: Flo (Italian (Italy))
#  - ID: com.apple.eloquence.it-IT.Flo
#  - Languages: ['it_IT']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 37:
#  - Name: Flo (Portuguese (Brazil))
#  - ID: com.apple.eloquence.pt-BR.Flo
#  - Languages: ['pt_BR']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 38:
#  - Name: Fred
#  - ID: com.apple.speech.synthesis.voice.Fred
#  - Languages: ['en_US']
#  - Gender: VoiceGenderMale
#  - Age: None
#
# Voice 39:
#  - Name: Good News
#  - ID: com.apple.speech.synthesis.voice.GoodNews
#  - Languages: ['en_US']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 40:
#  - Name: Grandma (German (Germany))
#  - ID: com.apple.eloquence.de-DE.Grandma
#  - Languages: ['de_DE']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 41:
#  - Name: Grandma (English (UK))
#  - ID: com.apple.eloquence.en-GB.Grandma
#  - Languages: ['en_GB']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 42:
#  - Name: Grandma (English (US))
#  - ID: com.apple.eloquence.en-US.Grandma
#  - Languages: ['en_US']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 43:
#  - Name: Grandma (Spanish (Spain))
#  - ID: com.apple.eloquence.es-ES.Grandma
#  - Languages: ['es_ES']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 44:
#  - Name: Grandma (Spanish (Mexico))
#  - ID: com.apple.eloquence.es-MX.Grandma
#  - Languages: ['es_MX']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 45:
#  - Name: Grandma (Finnish (Finland))
#  - ID: com.apple.eloquence.fi-FI.Grandma
#  - Languages: ['fi_FI']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 46:
#  - Name: Grandma (French (Canada))
#  - ID: com.apple.eloquence.fr-CA.Grandma
#  - Languages: ['fr_CA']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 47:
#  - Name: Grandma (French (France))
#  - ID: com.apple.eloquence.fr-FR.Grandma
#  - Languages: ['fr_FR']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 48:
#  - Name: Grandma (Italian (Italy))
#  - ID: com.apple.eloquence.it-IT.Grandma
#  - Languages: ['it_IT']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 49:
#  - Name: Grandma (Portuguese (Brazil))
#  - ID: com.apple.eloquence.pt-BR.Grandma
#  - Languages: ['pt_BR']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 50:
#  - Name: Grandpa (German (Germany))
#  - ID: com.apple.eloquence.de-DE.Grandpa
#  - Languages: ['de_DE']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 51:
#  - Name: Grandpa (English (UK))
#  - ID: com.apple.eloquence.en-GB.Grandpa
#  - Languages: ['en_GB']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 52:
#  - Name: Grandpa (English (US))
#  - ID: com.apple.eloquence.en-US.Grandpa
#  - Languages: ['en_US']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 53:
#  - Name: Grandpa (Spanish (Spain))
#  - ID: com.apple.eloquence.es-ES.Grandpa
#  - Languages: ['es_ES']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 54:
#  - Name: Grandpa (Spanish (Mexico))
#  - ID: com.apple.eloquence.es-MX.Grandpa
#  - Languages: ['es_MX']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 55:
#  - Name: Grandpa (Finnish (Finland))
#  - ID: com.apple.eloquence.fi-FI.Grandpa
#  - Languages: ['fi_FI']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 56:
#  - Name: Grandpa (French (Canada))
#  - ID: com.apple.eloquence.fr-CA.Grandpa
#  - Languages: ['fr_CA']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 57:
#  - Name: Grandpa (French (France))
#  - ID: com.apple.eloquence.fr-FR.Grandpa
#  - Languages: ['fr_FR']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 58:
#  - Name: Grandpa (Italian (Italy))
#  - ID: com.apple.eloquence.it-IT.Grandpa
#  - Languages: ['it_IT']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 59:
#  - Name: Grandpa (Portuguese (Brazil))
#  - ID: com.apple.eloquence.pt-BR.Grandpa
#  - Languages: ['pt_BR']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 60:
#  - Name: Jester
#  - ID: com.apple.speech.synthesis.voice.Hysterical
#  - Languages: ['en_US']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 61:
#  - Name: Ioana
#  - ID: com.apple.voice.compact.ro-RO.Ioana
#  - Languages: ['ro_RO']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 62:
#  - Name: Jacques
#  - ID: com.apple.eloquence.fr-FR.Jacques
#  - Languages: ['fr_FR']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 63:
#  - Name: Joana
#  - ID: com.apple.voice.compact.pt-PT.Joana
#  - Languages: ['pt_PT']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 64:
#  - Name: Junior
#  - ID: com.apple.speech.synthesis.voice.Junior
#  - Languages: ['en_US']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 65:
#  - Name: Kanya
#  - ID: com.apple.voice.compact.th-TH.Kanya
#  - Languages: ['th_TH']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 66:
#  - Name: Karen
#  - ID: com.apple.voice.compact.en-AU.Karen
#  - Languages: ['en_AU']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 67:
#  - Name: Kathy
#  - ID: com.apple.speech.synthesis.voice.Kathy
#  - Languages: ['en_US']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 68:
#  - Name: Kyoko
#  - ID: com.apple.voice.compact.ja-JP.Kyoko
#  - Languages: ['ja_JP']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 69:
#  - Name: Lana
#  - ID: com.apple.voice.compact.hr-HR.Lana
#  - Languages: ['hr_HR']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 70:
#  - Name: Laura
#  - ID: com.apple.voice.compact.sk-SK.Laura
#  - Languages: ['sk_SK']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 71:
#  - Name: Lekha
#  - ID: com.apple.voice.compact.hi-IN.Lekha
#  - Languages: ['hi_IN']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 72:
#  - Name: Lesya
#  - ID: com.apple.voice.compact.uk-UA.Lesya
#  - Languages: ['uk_UA']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 73:
#  - Name: Linh
#  - ID: com.apple.voice.compact.vi-VN.Linh
#  - Languages: ['vi_VN']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 74:
#  - Name: Luciana
#  - ID: com.apple.voice.compact.pt-BR.Luciana
#  - Languages: ['pt_BR']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 75:
#  - Name: Majed
#  - ID: com.apple.voice.compact.ar-001.Maged
#  - Languages: ['ar_001']
#  - Gender: VoiceGenderMale
#  - Age: None
#
# Voice 76:
#  - Name: Tünde
#  - ID: com.apple.voice.compact.hu-HU.Mariska
#  - Languages: ['hu_HU']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 77:
#  - Name: Meijia
#  - ID: com.apple.voice.compact.zh-TW.Meijia
#  - Languages: ['zh_TW']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 78:
#  - Name: Melina
#  - ID: com.apple.voice.compact.el-GR.Melina
#  - Languages: ['el_GR']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 79:
#  - Name: Milena
#  - ID: com.apple.voice.compact.ru-RU.Milena
#  - Languages: ['ru_RU']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 80:
#  - Name: Moira
#  - ID: com.apple.voice.compact.en-IE.Moira
#  - Languages: ['en_IE']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 81:
#  - Name: Mónica
#  - ID: com.apple.voice.compact.es-ES.Monica
#  - Languages: ['es_ES']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 82:
#  - Name: Montse
#  - ID: com.apple.voice.compact.ca-ES.Montserrat
#  - Languages: ['ca_ES']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 83:
#  - Name: Nora
#  - ID: com.apple.voice.compact.nb-NO.Nora
#  - Languages: ['nb_NO']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 84:
#  - Name: Organ
#  - ID: com.apple.speech.synthesis.voice.Organ
#  - Languages: ['en_US']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 85:
#  - Name: Paulina
#  - ID: com.apple.voice.compact.es-MX.Paulina
#  - Languages: ['es_MX']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 86:
#  - Name: Superstar
#  - ID: com.apple.speech.synthesis.voice.Princess
#  - Languages: ['en_US']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 87:
#  - Name: Ralph
#  - ID: com.apple.speech.synthesis.voice.Ralph
#  - Languages: ['en_US']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 88:
#  - Name: Reed (German (Germany))
#  - ID: com.apple.eloquence.de-DE.Reed
#  - Languages: ['de_DE']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 89:
#  - Name: Reed (English (UK))
#  - ID: com.apple.eloquence.en-GB.Reed
#  - Languages: ['en_GB']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 90:
#  - Name: Reed (English (US))
#  - ID: com.apple.eloquence.en-US.Reed
#  - Languages: ['en_US']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 91:
#  - Name: Reed (Spanish (Spain))
#  - ID: com.apple.eloquence.es-ES.Reed
#  - Languages: ['es_ES']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 92:
#  - Name: Reed (Spanish (Mexico))
#  - ID: com.apple.eloquence.es-MX.Reed
#  - Languages: ['es_MX']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 93:
#  - Name: Reed (Finnish (Finland))
#  - ID: com.apple.eloquence.fi-FI.Reed
#  - Languages: ['fi_FI']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 94:
#  - Name: Reed (French (Canada))
#  - ID: com.apple.eloquence.fr-CA.Reed
#  - Languages: ['fr_CA']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 95:
#  - Name: Reed (Italian (Italy))
#  - ID: com.apple.eloquence.it-IT.Reed
#  - Languages: ['it_IT']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 96:
#  - Name: Reed (Portuguese (Brazil))
#  - ID: com.apple.eloquence.pt-BR.Reed
#  - Languages: ['pt_BR']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 97:
#  - Name: Rishi
#  - ID: com.apple.voice.compact.en-IN.Rishi
#  - Languages: ['en_IN']
#  - Gender: VoiceGenderMale
#  - Age: None
#
# Voice 98:
#  - Name: Rocko (German (Germany))
#  - ID: com.apple.eloquence.de-DE.Rocko
#  - Languages: ['de_DE']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 99:
#  - Name: Rocko (English (UK))
#  - ID: com.apple.eloquence.en-GB.Rocko
#  - Languages: ['en_GB']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 100:
#  - Name: Rocko (English (US))
#  - ID: com.apple.eloquence.en-US.Rocko
#  - Languages: ['en_US']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 101:
#  - Name: Rocko (Spanish (Spain))
#  - ID: com.apple.eloquence.es-ES.Rocko
#  - Languages: ['es_ES']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 102:
#  - Name: Rocko (Spanish (Mexico))
#  - ID: com.apple.eloquence.es-MX.Rocko
#  - Languages: ['es_MX']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 103:
#  - Name: Rocko (Finnish (Finland))
#  - ID: com.apple.eloquence.fi-FI.Rocko
#  - Languages: ['fi_FI']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 104:
#  - Name: Rocko (French (Canada))
#  - ID: com.apple.eloquence.fr-CA.Rocko
#  - Languages: ['fr_CA']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 105:
#  - Name: Rocko (French (France))
#  - ID: com.apple.eloquence.fr-FR.Rocko
#  - Languages: ['fr_FR']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 106:
#  - Name: Rocko (Italian (Italy))
#  - ID: com.apple.eloquence.it-IT.Rocko
#  - Languages: ['it_IT']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 107:
#  - Name: Rocko (Portuguese (Brazil))
#  - ID: com.apple.eloquence.pt-BR.Rocko
#  - Languages: ['pt_BR']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 108:
#  - Name: Samantha
#  - ID: com.apple.voice.compact.en-US.Samantha
#  - Languages: ['en_US']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 109:
#  - Name: Sandy (German (Germany))
#  - ID: com.apple.eloquence.de-DE.Sandy
#  - Languages: ['de_DE']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 110:
#  - Name: Sandy (English (UK))
#  - ID: com.apple.eloquence.en-GB.Sandy
#  - Languages: ['en_GB']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 111:
#  - Name: Sandy (English (US))
#  - ID: com.apple.eloquence.en-US.Sandy
#  - Languages: ['en_US']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 112:
#  - Name: Sandy (Spanish (Spain))
#  - ID: com.apple.eloquence.es-ES.Sandy
#  - Languages: ['es_ES']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 113:
#  - Name: Sandy (Spanish (Mexico))
#  - ID: com.apple.eloquence.es-MX.Sandy
#  - Languages: ['es_MX']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 114:
#  - Name: Sandy (Finnish (Finland))
#  - ID: com.apple.eloquence.fi-FI.Sandy
#  - Languages: ['fi_FI']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 115:
#  - Name: Sandy (French (Canada))
#  - ID: com.apple.eloquence.fr-CA.Sandy
#  - Languages: ['fr_CA']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 116:
#  - Name: Sandy (French (France))
#  - ID: com.apple.eloquence.fr-FR.Sandy
#  - Languages: ['fr_FR']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 117:
#  - Name: Sandy (Italian (Italy))
#  - ID: com.apple.eloquence.it-IT.Sandy
#  - Languages: ['it_IT']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 118:
#  - Name: Sandy (Portuguese (Brazil))
#  - ID: com.apple.eloquence.pt-BR.Sandy
#  - Languages: ['pt_BR']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 119:
#  - Name: Sara
#  - ID: com.apple.voice.compact.da-DK.Sara
#  - Languages: ['da_DK']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 120:
#  - Name: Satu
#  - ID: com.apple.voice.compact.fi-FI.Satu
#  - Languages: ['fi_FI']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 121:
#  - Name: Shelley (German (Germany))
#  - ID: com.apple.eloquence.de-DE.Shelley
#  - Languages: ['de_DE']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 122:
#  - Name: Shelley (English (UK))
#  - ID: com.apple.eloquence.en-GB.Shelley
#  - Languages: ['en_GB']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 123:
#  - Name: Shelley (English (US))
#  - ID: com.apple.eloquence.en-US.Shelley
#  - Languages: ['en_US']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 124:
#  - Name: Shelley (Spanish (Spain))
#  - ID: com.apple.eloquence.es-ES.Shelley
#  - Languages: ['es_ES']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 125:
#  - Name: Shelley (Spanish (Mexico))
#  - ID: com.apple.eloquence.es-MX.Shelley
#  - Languages: ['es_MX']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 126:
#  - Name: Shelley (Finnish (Finland))
#  - ID: com.apple.eloquence.fi-FI.Shelley
#  - Languages: ['fi_FI']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 127:
#  - Name: Shelley (French (Canada))
#  - ID: com.apple.eloquence.fr-CA.Shelley
#  - Languages: ['fr_CA']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 128:
#  - Name: Shelley (French (France))
#  - ID: com.apple.eloquence.fr-FR.Shelley
#  - Languages: ['fr_FR']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 129:
#  - Name: Shelley (Italian (Italy))
#  - ID: com.apple.eloquence.it-IT.Shelley
#  - Languages: ['it_IT']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 130:
#  - Name: Shelley (Portuguese (Brazil))
#  - ID: com.apple.eloquence.pt-BR.Shelley
#  - Languages: ['pt_BR']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 131:
#  - Name: Sinji
#  - ID: com.apple.voice.compact.zh-HK.Sinji
#  - Languages: ['zh_HK']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 132:
#  - Name: Tessa
#  - ID: com.apple.voice.compact.en-ZA.Tessa
#  - Languages: ['en_ZA']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 133:
#  - Name: Thomas
#  - ID: com.apple.voice.compact.fr-FR.Thomas
#  - Languages: ['fr_FR']
#  - Gender: VoiceGenderMale
#  - Age: None
#
# Voice 134:
#  - Name: Tingting
#  - ID: com.apple.voice.compact.zh-CN.Tingting
#  - Languages: ['zh_CN']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 135:
#  - Name: Trinoids
#  - ID: com.apple.speech.synthesis.voice.Trinoids
#  - Languages: ['en_US']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 136:
#  - Name: Whisper
#  - ID: com.apple.speech.synthesis.voice.Whisper
#  - Languages: ['en_US']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 137:
#  - Name: Xander
#  - ID: com.apple.voice.compact.nl-NL.Xander
#  - Languages: ['nl_NL']
#  - Gender: VoiceGenderMale
#  - Age: None
#
# Voice 138:
#  - Name: Yelda
#  - ID: com.apple.voice.compact.tr-TR.Yelda
#  - Languages: ['tr_TR']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 139:
#  - Name: Yuna
#  - ID: com.apple.voice.compact.ko-KR.Yuna
#  - Languages: ['ko_KR']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 140:
#  - Name: Zarvox
#  - ID: com.apple.speech.synthesis.voice.Zarvox
#  - Languages: ['en_US']
#  - Gender: VoiceGenderNeuter
#  - Age: None
#
# Voice 141:
#  - Name: Zosia
#  - ID: com.apple.voice.compact.pl-PL.Zosia
#  - Languages: ['pl_PL']
#  - Gender: VoiceGenderFemale
#  - Age: None
#
# Voice 142:
#  - Name: Zuzana
#  - ID: com.apple.voice.compact.cs-CZ.Zuzana
#  - Languages: ['cs_CZ']
#  - Gender: VoiceGenderFemale
#  - Age: None

# %% [markdown]
# ## Trying out the audio book thing with a large chunk of text

# %% [markdown]
# #### Story made by ChatGPT
#
# Prompt: Can i get a short story that involves space travel, pirates, magical abilities, and crazy blackhole imps?

# %%
input_text = """In the vast reaches of the galaxy, aboard the starship Solaris, Captain Alyssa Blackwood and her crew sailed through the cosmic sea in pursuit of adventure and fortune. Their ship, a sleek vessel equipped with cutting-edge technology, was known across the star systems as both formidable and elusive. But this journey would take them beyond the ordinary plunder of space pirates.

Captain Blackwood's crew was a motley assembly of beings from different corners of the universe. There was K'Var, the hulking reptilian engineer with a knack for fixing anything; Rhiannon, the spirited navigator whose elven heritage granted her an affinity for the cosmic currents; and Zed, the tech-savvy robotic companion with a mysterious past.

One fateful day, while charting a course through the outer rim, the Solaris was ambushed by a notorious band of space pirates led by the cunning Captain Bloodfang. Blaster fire erupted across the void as the Solaris engaged in a desperate battle. Amidst the chaos, strange phenomena began to unfold.

As if summoned by the clash of vessels, a rift in spacetime appeared—a swirling, mesmerizing blackhole. From its depths emerged shadowy figures, mischievous imps wielding unpredictable magical powers. These were the legendary Blackhole Imps, notorious for their chaotic nature and insatiable curiosity.

In the heat of battle, Captain Blackwood's crew found themselves contending not only with pirates but also with these enigmatic beings. Rhiannon's elven magic clashed with the imp's whimsical spells, causing unpredictable anomalies to erupt throughout the ship. Meanwhile, Zed analyzed the blackhole's strange energies, attempting to decipher its secrets.

Despite the odds, the crew managed to repel the pirates, but Captain Bloodfang escaped, leaving the Solaris damaged and adrift near the blackhole. With their ship on the verge of collapse, Captain Blackwood made a bold decision—she would harness the power of the blackhole to repair their vessel and pursue their nemesis.

Guided by Rhiannon's mystical abilities and Zed's calculations, the crew ventured into the heart of the cosmic whirlpool, encountering more Blackhole Imps along the way. Each encounter brought new challenges and revelations, as the crew discovered the true nature of the imps' magic—a reflection of the chaotic forces of the universe itself.

In the climax of their journey, amidst the swirling energies of the blackhole, Captain Blackwood confronted Captain Bloodfang in a final showdown. The imps, intrigued by the clash of wills, unleashed their magic in a dazzling spectacle of light and shadow.

In the end, the Solaris emerged victorious, the pirates defeated and the crew forever changed by their encounter with the cosmic unknown. As they sailed away from the blackhole, the crew carried with them not just the spoils of their adventure but also a newfound respect for the mysteries of the universe—and perhaps a few mischievous Blackhole Imps hitching a ride among the stars."""

# %%
import time
import torch
import torchaudio
import sounddevice as sd
import numpy as np
import nltk
from nltk.tokenize import sent_tokenize
from TTS.tts.configs.xtts_config import XttsConfig
from TTS.tts.models.xtts import Xtts

# Download NLTK sentence tokenizer data
nltk.download('punkt')

print("Inference...")
t0 = time.time()

# Tokenize input text into sentences
sentences = sent_tokenize(input_text)

# Initialize an empty list to collect sentence audio waveforms
sentence_audio_waveforms = []

# Iterate over each sentence and synthesize audio
for i, sentence in enumerate(sentences):
    print(f"Synthesizing sentence {i + 1}: {sentence}")

    # Synthesize audio for the current sentence
    chunks = model.inference_stream(sentence, "en", gpt_cond_latent, speaker_embedding)

    # Collect all audio chunks for the current sentence
    sentence_audio_chunks = []
    for chunk in chunks:
        audio_numpy = chunk.squeeze().numpy()
        sentence_audio_chunks.append(audio_numpy)

    # Concatenate all audio chunks into a single waveform for the sentence
    sentence_audio_waveform = np.concatenate(sentence_audio_chunks)

    # Append the sentence audio waveform to the list of sentence waveforms
    sentence_audio_waveforms.append(sentence_audio_waveform)

# Concatenate all sentence audio waveforms into a single continuous waveform
audio_waveform = np.concatenate(sentence_audio_waveforms)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/darylroberts/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# /opt/anaconda3/lib/python3.11/site-packages/TTS/tts/layers/xtts/stream_generator.py:138: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation)
#   warnings.warn(
# Inference...
# Synthesizing sentence 1: In the vast reaches of the galaxy, aboard the starship Solaris, Captain Alyssa Blackwood and her crew sailed through the cosmic sea in pursuit of adventure and fortune.
# Synthesizing sentence 2: Their ship, a sleek vessel equipped with cutting-edge technology, was known across the star systems as both formidable and elusive.
# Synthesizing sentence 3: But this journey would take them beyond the ordinary plunder of space pirates.
# Synthesizing sentence 4: Captain Blackwood's crew was a motley assembly of beings from different corners of the universe.
# Synthesizing sentence 5: There was K'Var, the hulking reptilian engineer with a knack for fixing anything; Rhiannon, the spirited navigator whose elven heritage granted her an affinity for the cosmic currents; and Zed, the tech-savvy robotic companion with a mysterious past.
# Synthesizing sentence 6: One fateful day, while charting a course through the outer rim, the Solaris was ambushed by a notorious band of space pirates led by the cunning Captain Bloodfang.
# Synthesizing sentence 7: Blaster fire erupted across the void as the Solaris engaged in a desperate battle.
# Synthesizing sentence 8: Amidst the chaos, strange phenomena began to unfold.
# Synthesizing sentence 9: As if summoned by the clash of vessels, a rift in spacetime appeared—a swirling, mesmerizing blackhole.
# Synthesizing sentence 10: From its depths emerged shadowy figures, mischievous imps wielding unpredictable magical powers.
# Synthesizing sentence 11: These were the legendary Blackhole Imps, notorious for their chaotic nature and insatiable curiosity.
# Synthesizing sentence 12: In the heat of battle, Captain Blackwood's crew found themselves contending not only with pirates but also with these enigmatic beings.
# Synthesizing sentence 13: Rhiannon's elven magic clashed with the imp's whimsical spells, causing unpredictable anomalies to erupt throughout the ship.
# Synthesizing sentence 14: Meanwhile, Zed analyzed the blackhole's strange energies, attempting to decipher its secrets.
# Synthesizing sentence 15: Despite the odds, the crew managed to repel the pirates, but Captain Bloodfang escaped, leaving the Solaris damaged and adrift near the blackhole.
# Synthesizing sentence 16: With their ship on the verge of collapse, Captain Blackwood made a bold decision—she would harness the power of the blackhole to repair their vessel and pursue their nemesis.
# Synthesizing sentence 17: Guided by Rhiannon's mystical abilities and Zed's calculations, the crew ventured into the heart of the cosmic whirlpool, encountering more Blackhole Imps along the way.
# Synthesizing sentence 18: Each encounter brought new challenges and revelations, as the crew discovered the true nature of the imps' magic—a reflection of the chaotic forces of the universe itself.
# Synthesizing sentence 19: In the climax of their journey, amidst the swirling energies of the blackhole, Captain Blackwood confronted Captain Bloodfang in a final showdown.
# Synthesizing sentence 20: The imps, intrigued by the clash of wills, unleashed their magic in a dazzling spectacle of light and shadow.
# Synthesizing sentence 21: In the end, the Solaris emerged victorious, the pirates defeated and the crew forever changed by their encounter with the cosmic unknown.
# Synthesizing sentence 22: As they sailed away from the blackhole, the crew carried with them not just the spoils of their adventure but also a newfound respect for the mysteries of the universe—and perhaps a few mischievous Blackhole Imps hitching a ride among the stars.

# %%
display(Audio(data=audio_waveform, rate=24000, autoplay=False))
