# %% [markdown]
# # Twig: A Webserial to AudioBook

# %% [markdown]
# ## Famously "Wildbow" an online writer does not have audio books for his writing.
#
# Since I am often too busy to really stop and read, I would like to turn a story I have yet to read into an audio book

# %% [markdown]
# ## Engine to split sentences

# %%
import re

def split_sentences_with_punctuation(text):
    # Define regex pattern to match sentence-ending punctuation
    pattern = r'([.!?]+)'

    # Use regex to split text into sentences based on the pattern
    sentences = re.split(pattern, text)

    # Combine sentences with their respective punctuation marks
    combined_sentences = []
    i = 0
    while i < len(sentences) - 1:
        sentence = sentences[i].strip()
        punctuation = sentences[i + 1] if i + 1 < len(sentences) else ''
        combined_sentence = sentence + punctuation
        combined_sentences.append(combined_sentence)
        i += 2

    return combined_sentences

# %%
import torch
import torchaudio
import TTS

print(f"torch version: {torch.__version__}")
print(f"torchaudio version: {torchaudio.__version__}")
print(f"TTS version: {TTS.__version__}")
# Out:
# torch version: 2.2.2
# torchaudio version: 2.2.2
# TTS version: 0.22.0

# %% [markdown]
# ## Bringing in my trained voice model from the guy that reads "I am Legend"

# %%
import os
import torch
import torchaudio
from TTS.tts.configs.xtts_config import XttsConfig
from TTS.tts.models.xtts import Xtts

print("Loading model...")
config = XttsConfig()
config.load_json("voice_model/config.json")
model = Xtts.init_from_config(config)
model.load_checkpoint(config, checkpoint_dir='voice_model/')

print("Computing speaker latents...")
gpt_cond_latent, speaker_embedding = model.get_conditioning_latents(audio_path=["reference_audio/IAmLegend_ep6 - 017.wav"])
# Out:
# Loading model...
# Computing speaker latents...

# %% [markdown]
# ## Copying in Chapter 1 of the webserial

# %%
chapter1 = """
Taking Root One point One.
How does it go?  The first lesson, something even the uninitiated know.  For life to flourish on the most basic level, it requires four elements.  Carbon, oxygen, nitrogen and hydrogen.

We were doing fine on that count.  The air around us was stale, but it was still oxygen.  Water ran around and below us, flowing over our bare feet, redirected from gutters to the building’s inside.

What had once been a barn had been made into a warehouse, then abandoned partway through a third set of changes.  A floor of old wooden slats reached only halfway down the length of the old building, what had once been a hayloft.  If we stood on the edge, we could look down at the floor below to see uneven floorboards on top of compacted dirt.  The original barn’s door was still there, mounted on rollers.  I leaned over to get a better look.  I could see a table, some scattered papers, books, and a blackboard.  The only light was that which came in through windows.  A scattered set placed on the upper floor, and more well above head height on the lower one.

Aside from the four of us, one other thing occupied the hayloft.  It was hard to make out in the dim light that filtered in through the window, like an eel in dark water, and if it weren’t for the fact that we’d seen it approach, we might not have noticed it at all.  Sleek, four-legged, and tall enough I couldn’t have reached its shoulder if I stood on my toes, it was wound around the pillar as a snake might be.  Unlike a snake, though, it had four long limbs, each with four long digits, tipped with claws.  Head flowed into neck, which flowed into shoulder and body without a without prominent ridge, bump, bone or muscle to interrupt the sequence.

It uncoiled, setting a claw on the floor, and the old floorboards didn’t elicit an audible creak.  Large as it was, it managed to distribute weight too evenly, and used its tail to suspend some of its weight.

It didn’t walk, but slinked, each foot falling in front of the last as it passed within three feet of us.  Its wide mouth parted, showing just a hint of narrow white teeth.

There was no cover, nothing to hide us from it.

I saw its nostrils flare.  It opened its mouth to taste the air with a flick of a thin tongue.

“Try it,” the snake charmer said.

Gordon did.  He approached, and the snake charmer tried to grab him.

The man’s hands only grabbed clothes.  A hood and cloak meant to keep the rain off.  Gordon let him, and ducked low, the clothing bunching up around his neck and upper chest.

Gordon sliced the snake charmer’s stomach.  A shallow cut.

Another grab, wrestling Gordon, trying to overpower with strength, seizing one arm.

Gordon let the knife drop out of one hand, falling into the palm of another.

He cut the back of the man’s left knee.  When the man fell, screaming, Gordon cut the other knee.  He skipped back as the snake charmer fell.

The snake stirred, its attention no longer predominantly on me.

I could see the snake charmer realizing the same thing I had minutes ago.  He knew his experiment.  He knew how it hunted.  It scavenged, sniffing out prey.  Blind, it reacted to noise and smell.  Minimizing the noise one made was vital.

Given the situation, however, staying silent spelled the man’s doom.  Already, his creation was sniffing him out.  He smelled of blood.

“Pheromones,” he said, knowing how dangerous it was to speak, that every sound helped him lose the tug of war that let the creature decide between devouring him and devouring me.  “Let me- I’ll come with you.  You can take me in.  You win.”

Nobody moved or responded.

He used his arms to pull himself forward, progressing toward the table.  Each motion drew more attention from his beast.

Foot by foot, he closed on the table, and each sound was akin to a fisherman’s line, reeling in the beast.

He reached the table, struggling, and he raised himself up, using one hand to drag a leg forward, propping it under him.  Reaching across the table-

Gordon kicked the leg of the table, hard.  The table shifted a foot, and the snake charmer collapsed.

“No.  Please.”

The snake charmer looked at us.  At Gordon, then Helen, who loomed above, perched on the hayloft.  At me, as I glared at him, my face burned.  At Lillian, who was sitting in the corner, hands over her head.

Who was not one of us.

“Please,” he said.  “Not like this.”

Helen’s expression didn’t change.  Gordon shifted his position, placing himself between the snake charmer and the table, arms folded.  I remained where I was, limp and breathing hard.

I could see it dawn on the man.  Comprehension settling in as he realized what he was dealing with.

The snake seized the man’s feet, and began the very slow process of swallowing him.

The snake charmer’s screams became frantic.

“Lillian,” Gordon said, raising his voice to be heard over the screams.

“I don’t want to see.”

“Then shield your eyes.  But your job is to keep us in one piece.  Sly is hurt.  Focus, and make sure he doesn’t die.”

I felt the burning stop as Lillian tended to me.  By the time she was done, the screams had stopped.  The powder that dusted me made it hard to see, but that was fine.  I was lifted to my feet.

“I have to say, I’m very interested in what the fuck you were doing, faking that fall, setting yourself up to get hurt just now,” Gordon said.  “You’ll have to tell me later, when you can talk again.”

I managed a nod.

“Off we go,” he said.

I could hear the door open.

Helen spoke for the first time in a while.  Her voice was cute.  “The Academy sends its regards, Mr. Snake Charmer.”"""

# %% [markdown]
# ## Split the chapter into sentences the voice model can iterate over

# %%
import time
import torch
import torchaudio
import sounddevice as sd
import numpy as np
import nltk
from nltk.tokenize import sent_tokenize
from TTS.tts.configs.xtts_config import XttsConfig
from TTS.tts.models.xtts import Xtts

# Download NLTK sentence tokenizer data
nltk.download('punkt')

print("Inference...")
t0 = time.time()

# Tokenize input text into sentences
sentences = sent_tokenize(chapter1)

# Initialize an empty list to collect sentence audio waveforms
sentence_audio_waveforms = []

# Iterate over each sentence and synthesize audio
for i, sentence in enumerate(sentences):
    print(f"Synthesizing sentence {i + 1}: {sentence}")

    # Synthesize audio for the current sentence
    chunks = model.inference_stream(sentence, "en", gpt_cond_latent, speaker_embedding)

    # Collect all audio chunks for the current sentence
    sentence_audio_chunks = []
    for chunk in chunks:
        audio_numpy = chunk.squeeze().numpy()
        sentence_audio_chunks.append(audio_numpy)

    # Concatenate all audio chunks into a single waveform for the sentence
    sentence_audio_waveform = np.concatenate(sentence_audio_chunks)

    # Append the sentence audio waveform to the list of sentence waveforms
    sentence_audio_waveforms.append(sentence_audio_waveform)

# Concatenate all sentence audio waveforms into a single continuous waveform
audio_waveform = np.concatenate(sentence_audio_waveforms)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/darylroberts/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# /opt/anaconda3/lib/python3.11/site-packages/TTS/tts/layers/xtts/stream_generator.py:138: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation)
#   warnings.warn(
# Inference...
# Synthesizing sentence 1:
# Taking Root One point One.
# Synthesizing sentence 2: How does it go?
# Synthesizing sentence 3: The first lesson, something even the uninitiated know.
# Synthesizing sentence 4: For life to flourish on the most basic level, it requires four elements.
# Synthesizing sentence 5: Carbon, oxygen, nitrogen and hydrogen.
# Synthesizing sentence 6: We were doing fine on that count.
# Synthesizing sentence 7: The air around us was stale, but it was still oxygen.
# Synthesizing sentence 8: Water ran around and below us, flowing over our bare feet, redirected from gutters to the building’s inside.
# Synthesizing sentence 9: What had once been a barn had been made into a warehouse, then abandoned partway through a third set of changes.
# Synthesizing sentence 10: A floor of old wooden slats reached only halfway down the length of the old building, what had once been a hayloft.
# Synthesizing sentence 11: If we stood on the edge, we could look down at the floor below to see uneven floorboards on top of compacted dirt.
# Synthesizing sentence 12: The original barn’s door was still there, mounted on rollers.
# Synthesizing sentence 13: I leaned over to get a better look.
# Synthesizing sentence 14: I could see a table, some scattered papers, books, and a blackboard.
# Synthesizing sentence 15: The only light was that which came in through windows.
# Synthesizing sentence 16: A scattered set placed on the upper floor, and more well above head height on the lower one.
# Synthesizing sentence 17: Aside from the four of us, one other thing occupied the hayloft.
# Synthesizing sentence 18: It was hard to make out in the dim light that filtered in through the window, like an eel in dark water, and if it weren’t for the fact that we’d seen it approach, we might not have noticed it at all.
# Synthesizing sentence 19: Sleek, four-legged, and tall enough I couldn’t have reached its shoulder if I stood on my toes, it was wound around the pillar as a snake might be.
# Synthesizing sentence 20: Unlike a snake, though, it had four long limbs, each with four long digits, tipped with claws.
# Synthesizing sentence 21: Head flowed into neck, which flowed into shoulder and body without a without prominent ridge, bump, bone or muscle to interrupt the sequence.
# Synthesizing sentence 22: It uncoiled, setting a claw on the floor, and the old floorboards didn’t elicit an audible creak.
# Synthesizing sentence 23: Large as it was, it managed to distribute weight too evenly, and used its tail to suspend some of its weight.
# Synthesizing sentence 24: It didn’t walk, but slinked, each foot falling in front of the last as it passed within three feet of us.
# Synthesizing sentence 25: Its wide mouth parted, showing just a hint of narrow white teeth.
# Synthesizing sentence 26: There was no cover, nothing to hide us from it.
# Synthesizing sentence 27: I saw its nostrils flare.
# Synthesizing sentence 28: It opened its mouth to taste the air with a flick of a thin tongue.
# Synthesizing sentence 29: The way things looked, we were very close to doing the opposite of ‘flourishing’.
# Synthesizing sentence 30: It was hard to put into words, but my thoughts connected with that thought, and it was funny.
# Synthesizing sentence 31: I grinned, and flakes of wax fell from my face at the movement.
# Synthesizing sentence 32: I watched the thing continue onward, toward the back of the hayloft, head turning as it sniffed the surroundings.
# Synthesizing sentence 33: It unwound its long tail from the wooden pillar that held up the one end of the overhanging hayloft, and it moved with a slow carefulness.
# Synthesizing sentence 34: I stared at its eye, and saw how it didn’t move as the head swept from one side to the next, the slit of the iris barely changing in response as the faint light from the window swept over its head.
# Synthesizing sentence 35: “It’s blind,” I whispered.
# Synthesizing sentence 36: The movements of the creature came to a halt.
# Synthesizing sentence 37: It froze, nostrils wide.
# Synthesizing sentence 38: Gordon, just to my left, put out a hand, covering my mouth.
# Synthesizing sentence 39: He was tense, lines on his neck standing out.
# Synthesizing sentence 40: Trying to put on a brave face, as our leader.
# Synthesizing sentence 41: Gordon, strong, handsome, likeable, talented.
# Synthesizing sentence 42: A veneer covered his face, as it did all of us, almost clear, cracked and white at the corners of his lips where he’d changed his expression, coming away in flakes at his hairline, where his hair was covered by the same substance.
# Synthesizing sentence 43: The creature turned, and as it did its tail moved around until it touched the outside edge of the makeshift gutter that we were all standing in, fine emerald scales rasping against wood.
# Synthesizing sentence 44: When Gordon whispered his response, I could barely hear him utter, “It’s not deaf.”
#
# I nodded, and he pulled his hand away.
# Synthesizing sentence 45: I had a glimpse of the girls.
# Synthesizing sentence 46: Helen and Lillian.
# Synthesizing sentence 47: As different as night and day.
# Synthesizing sentence 48: Lillian was bent over, hood up and over her head, hiding her face, hands clutching the straps of her bag, white knuckled.
# Synthesizing sentence 49: Terrified, and rightly so.
# Synthesizing sentence 50: The coating on her face was flaking badly.
# Synthesizing sentence 51: In contrast, Helen’s face didn’t betray a flicker of emotion.
# Synthesizing sentence 52: Her golden hair, normally well cared for, cultivated into tight rolls, was damp and falling out of place.
# Synthesizing sentence 53: Water ran down her face, splashing in through the side of the window where the makeshift gutter came in, and the droplets didn’t provoke one flinch or batted eyelash.
# Synthesizing sentence 54: She could have been a statue, and she’d kept her face still enough that the wax that covered it hadn’t broken, which only helped the effect.
# Synthesizing sentence 55: Still and silent, we watched as the creature moved to the far corner of the hayloft.
# Synthesizing sentence 56: It snapped, and the four curved fangs were the only ones that were any wider than a pencil, visible for only an instant before the head disappeared into detritus piled in the corner.
# Synthesizing sentence 57: A furred form struggled before the creature could raise its head.
# Synthesizing sentence 58: No swallowing, per se.
# Synthesizing sentence 59: Gravity did the work, as teeth parted and the prey fell down its long throat.
# Synthesizing sentence 60: A second bite let it collect another, small and young enough it couldn’t even struggle.
# Synthesizing sentence 61: Tiny morsels.
# Synthesizing sentence 62: “Kitties,” Lillian whispered, horror overtaking fear in her expression.
# Synthesizing sentence 63: Mama kitty shouldn’t have had her babies in the same building as the monster, I thought.
# Synthesizing sentence 64: Wallace’s law at work.
# Synthesizing sentence 65: Gordon nudged me.
# Synthesizing sentence 66: He pointed.
# Synthesizing sentence 67: The window.
# Synthesizing sentence 68: I nodded.
# Synthesizing sentence 69: The makeshift gutter was little more than a trough, with little care given for the leaks here and there, and it fed into wooden barrels at the edge of the upper floor, with more channels and troughs leading into sub-chambers and tanks below.
# Synthesizing sentence 70: It had been running long enough for debris and grime to accumulate, a combination of silt and scum collecting at the very bottom to make it treacherous.
# Synthesizing sentence 71: Our progress was slow, and I had to remind myself that anything faster threatened to make noise, or risked a fall.
# Synthesizing sentence 72: As if to follow the thought, Lillian’s foot skidded on the bottom of the trough, and she tipped forward, straight into Helen’s arms.
# Synthesizing sentence 73: The creature stopped its slow consumption of the cat’s litter.
# Synthesizing sentence 74: We were frozen, waiting, while the creature sniffed the air.
# Synthesizing sentence 75: It returned to its meal.
# Synthesizing sentence 76: We made our way out, everyone but me flipping up their hoods to ward off the rain.
# Synthesizing sentence 77: I let the droplets fall where they would, on hair that refused to be bound down beneath a thick layer of waterproofing wax.
# Synthesizing sentence 78: There was no ledge outside the window, only the real gutter.
# Synthesizing sentence 79: Bigger and more solid, if still treacherous with seasons of accumulated grime.
# Synthesizing sentence 80: The roof loomed above us, more up than over, as barn roofs were wont to be.
# Synthesizing sentence 81: Red leaves collected here and there.
# Synthesizing sentence 82: “I stay,” Helen murmured.
# Synthesizing sentence 83: There was no questioning it, no argument.
# Synthesizing sentence 84: We couldn’t afford to make the noise, and it made a degree of sense.
# Synthesizing sentence 85: “I’ll go first,” I volunteered, craning my head a bit to see the way down.
# Synthesizing sentence 86: Being the sort of building it was, the barn-turned-warehouse-turned-something-else was tall, with a long way to the bottom.
# Synthesizing sentence 87: The gutter pointed groundward at the corner, fixed to the brick exterior at regular points by lengths of metal.
# Synthesizing sentence 88: It worked as a ladder, but not one that was fun to use.
# Synthesizing sentence 89: The ‘rungs’ were too far apart, too close to the wall.
# Synthesizing sentence 90: Someone grabbed my arm.
# Synthesizing sentence 91: I thought it would be Gordon or Helen, as they had the personalities to be arm-grabbers.
# Synthesizing sentence 92: It wasn’t.
# Synthesizing sentence 93: “You go second,” Lillian whispered to me.
# Synthesizing sentence 94: “I know you well enough to know that If you go before me you’ll look up my skirt.”
#
# “Me?” I tried to sound innocent.
# Synthesizing sentence 95: Gordon jabbed me.
# Synthesizing sentence 96: His expression was no-nonsense, his green eyes a steely grey beneath his hood, absorbing the colors of the clouds above.
# Synthesizing sentence 97: His mouth was a grim line.
# Synthesizing sentence 98: “Okay,” I conceded.
# Synthesizing sentence 99: “I’ll take your bag,” Gordon whispered.
# Synthesizing sentence 100: Again, there was no argument.
# Synthesizing sentence 101: Lillian handed over the backpack, loaded down with tools and supplies.
# Synthesizing sentence 102: She accepted Gordon’s support in getting down to the downspout, and began her slow descent.
# Synthesizing sentence 103: I fidgeted.
# Synthesizing sentence 104: My eye traveled over our surroundings, buildings scattered like they’d been blown around by strong winds and planted where they lay.
# Synthesizing sentence 105: Older structures had a charm to them, simplicity and a character that came with age and gentle wear and tear.
# Synthesizing sentence 106: The oldest and the newest buildings had been shored up by strategic plant growth, branches weaving into and through damaged sections, growing to complement masonry, around bricks and supports.
# Synthesizing sentence 107: The very newest growths had a characteristic red tint to the leaves.
# Synthesizing sentence 108: The rest were dead, left to petrify.
# Synthesizing sentence 109: The Academy loomed above it all, those same elements taken to an extreme.
# Synthesizing sentence 110: It had been an old collection of buildings once.
# Synthesizing sentence 111: A rush to grow and meet surging demand had led to a lot of the same haphazard growth.
# Synthesizing sentence 112: It all had an odor.
# Synthesizing sentence 113: There were smells that became second nature, and there were smells that were ingrained in the psyche as bad smells.
# Synthesizing sentence 114: Ones that spoke of death, of long sickness, and of violence.
# Synthesizing sentence 115: Rendered fat, decay, and blood.
# Synthesizing sentence 116: Each were heavy on the air.
# Synthesizing sentence 117: Ironic, that things so overgrown and reeking of decay were the parts of the city charged with progress.
# Synthesizing sentence 118: You’d think the rain would wash away the smell.
# Synthesizing sentence 119: I checked.
# Synthesizing sentence 120: Lillian had moved down one rung.
# Synthesizing sentence 121: I shifted my weight from one foot to the next, annoyed.
# Synthesizing sentence 122: She wasn’t one of us.
# Synthesizing sentence 123: She was new.
# Synthesizing sentence 124: Allowances had to be made.
# Synthesizing sentence 125: It wasn’t the first time I had told myself any of those things.
# Synthesizing sentence 126: I’d heard it from Gordon.
# Synthesizing sentence 127: It didn’t make it any less annoying.
# Synthesizing sentence 128: I bent down, peering over the edge of the gutter to the road below.
# Synthesizing sentence 129: I could see the windows, the boxes further down.
# Synthesizing sentence 130: “Sy,” Gordon hissed the words, “What are you doing?”
#
# Gripping the ledge, I swung myself over.
# Synthesizing sentence 131: I let go, and enjoyed both the moment of utter terror and Lillian’s gasp of horror, before my fingers caught hold of the window frame below.
# Synthesizing sentence 132: My right foot slipped on the damp windowsill, scraping peeling paint off and away before I brought it back up to the sill.
# Synthesizing sentence 133: Water and paint flakes sprayed below.
# Synthesizing sentence 134: When I looked up, Gordon’s head was poking over the edge, looking down at me.
# Synthesizing sentence 135: He moved his head, and I could hear him speak, very patiently, to Lillian, “Keep going.
# Synthesizing sentence 136: Don’t mind him.”
#
# Peering in the window, I could see the interior, the lower floor.
# Synthesizing sentence 137: The desk, the notes on the experiment.
# Synthesizing sentence 138: Another table was heavy with lines of bottles, vials, jugs, and yet more papers, scattered.
# Synthesizing sentence 139: Rain poured down on me, tracing its way down the back of my neck, beneath my shirt.
# Synthesizing sentence 140: The waxed and waterproof cowl and short cloak had kept my shirt dry, and I shivered at the sensation.
# Synthesizing sentence 141: I tested the window, and was utterly surprised to find it latched.
# Synthesizing sentence 142: I drew a key from my pocket, trying to fit it into the gap, hoping to lift the latch, but it proved too thick.
# Synthesizing sentence 143: The key went back in place.
# Synthesizing sentence 144: I removed my hands from the windowsill one at a time, to dry them in my armpits and then reposition my grip.
# Synthesizing sentence 145: Gripping the windowsill, I strained my body, reaching down and to the right.
# Synthesizing sentence 146: The doorframe that bounded the large sliding door was just out of reach…
#
# Holding the windowsill with my left hand, reaching with my right leg, I touched the frame with my big toe.
# Synthesizing sentence 147: I found a grip, and I used it to better position myself.
# Synthesizing sentence 148: Fingers dug into the space between bricks, where water had worn away mortar, and I heaved myself over, using my toes and only my toes to perch on the top of the doorway.
# Synthesizing sentence 149: Were it any other door, I wouldn’t have fussed, but I was still just high enough off the ground to have cause to worry.
# Synthesizing sentence 150: This had been a barn, and this door was the type that let wagons or draft horses inside.
# Synthesizing sentence 151: I paused on top of the door, cleaning my hands of wet and grit.
# Synthesizing sentence 152: “Watching you do that is making me nervous,” Lillian said, looking down at me.
# Synthesizing sentence 153: She’d progressed two more ‘rungs’.
# Synthesizing sentence 154: She was the shortest of us, next to me, it didn’t make it easier for her.
# Synthesizing sentence 155: I flashed her a grin, and more of the waterproofing wax that I’d caked onto my face cracked.
# Synthesizing sentence 156: I worked my way down to a crouch, still on top of the door, then slid down, draping my front against the door itself.
# Synthesizing sentence 157: I let myself drop the rest of the way, landing bare-footed in mud.
# Synthesizing sentence 158: I couldn’t get the smile off my face as I passed beneath the drain pipe, making a point of looking up at Lillian, who was making a point of her own in turn, glaring down at me, very clearly annoyed.
# Synthesizing sentence 159: “You had an audience,” a soft voice stated.
# Synthesizing sentence 160: I turned.
# Synthesizing sentence 161: Amid empty crates and a door that had been taken off its hinges, jumbled together as trash and detritus, I could make out the fifth member of our contingent.
# Synthesizing sentence 162: Jamie had a book in his lap, our collected boots and shoes neatly organized around him, and he had company.
# Synthesizing sentence 163: A black-skinned boy with a hood and cloak far too large for him, tattered enough that it had probably been a hand-me-down for the last person to own it.
# Synthesizing sentence 164: His eyes were wide.
# Synthesizing sentence 165: “I thought you were keeping lookout,” I said.
# Synthesizing sentence 166: “I was.”
#
# “The whole point of being lookout is that you tell us if there’s trouble.”
#
# “Is he trouble?”  Jamie asked.
# Synthesizing sentence 167: “I’m no trouble,” the boy’s words flowed right off the back of Jamie’s, without a heartbeat of hesitation.
# Synthesizing sentence 168: “The trouble is inside.”
#
# “The snake thing,” I said.
# Synthesizing sentence 169: “You saw it?” he asked.
# Synthesizing sentence 170: His eyes went wider.
# Synthesizing sentence 171: “Then you should know if you’re going to steal something, you shouldn’t steal from there.”
#
# “We’re not stealing,” I said.
# Synthesizing sentence 172: “We’re just looking.”
#
# The boy didn’t respond.
# Synthesizing sentence 173: He watched Lillian’s glacially slow descent.
# Synthesizing sentence 174: I met Jamie’s eyes.
# Synthesizing sentence 175: If it weren’t for Helen, who was a special case, I might have called Jamie the quiet one.
# Synthesizing sentence 176: He wore eyeglasses, though there were all sorts of ways to fix or replace bad eyes, and his hair was long beneath his hood.
# Synthesizing sentence 177: Not out of any style or affectation.
# Synthesizing sentence 178: He simply never liked how it looked when it was short.
# Synthesizing sentence 179: His face was narrow, his eyes large as he shifted his gaze to look from me to Lillian.
# Synthesizing sentence 180: His hands held firm to a book that sat across his knees.
# Synthesizing sentence 181: “Helen?” he asked.
# Synthesizing sentence 182: “Stayed upstairs.”
#
# A nod.
# Synthesizing sentence 183: I wanted him to figure out how to deal with our bystander, given how he’d failed to warn us about the boy in the first place, but Jamie was silent.
# Synthesizing sentence 184: “What’s your name?” I asked.
# Synthesizing sentence 185: “Mine?”
#
# “I know his,” I said, striving to not sound as annoyed at the question as I felt.
# Synthesizing sentence 186: I pointed at Jamie to make myself as clear as possible.
# Synthesizing sentence 187: “Thomas.
# Synthesizing sentence 188: My friends call me Thom.”
#
# “Did you hear about the crying man of Butcher’s Row?”
#
# “Sly,” Jamie said, suddenly paying attention to the issue.
# Synthesizing sentence 189: The name was a warning.
# Synthesizing sentence 190: But Thom gave an answer, “That stitched that went crazy.
# Synthesizing sentence 191: Remembered things.”
#
# “That’s the one.
# Synthesizing sentence 192: Do you remember Mother Hen?”
#
# Thom nodded.
# Synthesizing sentence 193: “That nurse who- the babies.”
#
# He looked rather uneasy now.
# Synthesizing sentence 194: “That’s right,” I said, doing my best to sound calm, reassuring.
# Synthesizing sentence 195: “The nurse.
# Synthesizing sentence 196: Yes.
# Synthesizing sentence 197: Both got caught, right?
# Synthesizing sentence 198: Everything got tied up neatly?”
#
# “Yeah,” Thom said.
# Synthesizing sentence 199: He couldn’t meet my eyes, so he focused on Lillian instead.
# Synthesizing sentence 200: “The authorities from the Academy got them.”
#
# “Exactly, Thom,” I said, “But who told the authorities?”
#
# His eyes moved.
# Synthesizing sentence 201: To me, then Jamie, to Lillian, and then the barn-turned-warehouse.
# Synthesizing sentence 202: I was nodding before the word came out of his mouth.
# Synthesizing sentence 203: “You.”
#
# “You’re clever,” I praised him.
# Synthesizing sentence 204: “Why?”
#
# I made the universal gesture for money, rubbing thumb against two fingers.
# Synthesizing sentence 205: “Really?”
#
# I nodded.
# Synthesizing sentence 206: The gears were shifting in his head.
# Synthesizing sentence 207: Processing, calculating.
# Synthesizing sentence 208: “I’ve heard things,” he said.
# Synthesizing sentence 209: “I bet.”
#
# “Useful things.”
#
# “I don’t doubt it,” I said.
# Synthesizing sentence 210: “I can get money for it?
# Synthesizing sentence 211: For telling people?”
#
# “If you know who to tell, and how to sell it,” I said.
# Synthesizing sentence 212: His expression changed, a frown.
# Synthesizing sentence 213: Disappointment.
# Synthesizing sentence 214: Tick, tick, turn turn.
# Synthesizing sentence 215: The gears in his head were still moving.
# Synthesizing sentence 216: He wasn’t dumb, even if he wasn’t much of an actor.
# Synthesizing sentence 217: Then again, he was only ten or so.
# Synthesizing sentence 218: I could guess what he was going to ask, and I knew I might lose him if I turned him down too many times.
# Synthesizing sentence 219: My mind ticked over possibilities.
# Synthesizing sentence 220: What I needed, what I had to do.
# Synthesizing sentence 221: Before he could venture a question, I interrupted him.
# Synthesizing sentence 222: “You want in?”
#
# “In?” he asked.
# Synthesizing sentence 223: Now he was wary.
# Synthesizing sentence 224: I reached beneath my cloak, and I fished out a coinpurse.
# Synthesizing sentence 225: Two fingers reached in, and came out fully extended, two dollars in coins pressed between the tips.
# Synthesizing sentence 226: The wariness subsided.
# Synthesizing sentence 227: “I’ll give you this on good faith.
# Synthesizing sentence 228: Eight whole dollars if you follow through.
# Synthesizing sentence 229: I need you to do something for me.”
#
# He reached for and claimed the money without any hesitation.
# Synthesizing sentence 230: “You said you had friends?” I asked.
# Synthesizing sentence 231: “Sure.”
#
# “On top of the grocer’s place.
# Synthesizing sentence 232: Corner of Oxbow and Halls.
# Synthesizing sentence 233: Wait there.
# Synthesizing sentence 234: Take turns keeping an eye out.
# Synthesizing sentence 235: You’re looking for a black coach, led by two stitched horses, heading toward the Academy.
# Synthesizing sentence 236: You’ll know they’re stitched because they’re wearing raincoats.
# Synthesizing sentence 237: Won’t be more than two hours’ wait.”
#
# “Uh huh?”
#
# “There’s a rain barrel up there.
# Synthesizing sentence 238: They’re going to have to stop to wait for the way to clear before they can carry on their way.
# Synthesizing sentence 239: What you’re going to do is tip over the barrel.
# Synthesizing sentence 240: Send water off the edge of the roof, onto the horses if you can.
# Synthesizing sentence 241: Might want to prop some things up around the barrel, to make sure it happens.”
#
# He frowned a bit.
# Synthesizing sentence 242: “Ten dollars, all in all, for you and your friends, for one afternoon’s work.
# Synthesizing sentence 243: Pretty good deal.
# Synthesizing sentence 244: Don’t think you can do it?”
#
# “I can do it,” Thom said.
# Synthesizing sentence 245: “You sure?” I asked.
# Synthesizing sentence 246: “I can do it,” he said, voice firm.
# Synthesizing sentence 247: I studied him, head to toe, taking it all in.
# Synthesizing sentence 248: Reaching beneath my cloak, I collected a note from a pocket.
# Synthesizing sentence 249: I pressed it into his hands.
# Synthesizing sentence 250: He looked down at the money, stunned.
# Synthesizing sentence 251: “If you don’t follow through, you won’t get a deal like this again,” I said.
# Synthesizing sentence 252: “Think hard before you try cheating me.
# Synthesizing sentence 253: A big part of what we do is find people.”
#
# Mute, he nodded.
# Synthesizing sentence 254: “Go,” I said.
# Synthesizing sentence 255: He went, running, feet splashing in puddles of water.
# Synthesizing sentence 256: Lillian was about halfway down.
# Synthesizing sentence 257: “You lied to him,” Jamie said.
# Synthesizing sentence 258: “Would you rather I told the truth?” I asked.
# Synthesizing sentence 259: “If you’re going to get him involved.”
#
# I shook my head.
# Synthesizing sentence 260: “Which leads me to ask… what are you up to?” Jamie asked.
# Synthesizing sentence 261: “You weren’t just getting rid of him or making trouble.”
#
# “I’m going inside,” I said, starting for the door.
# Synthesizing sentence 262: “Tell the others if they’re wondering.”
#
# “That’s not what I’m asking,” Jamie said.
# Synthesizing sentence 263: But he didn’t move from his spot, and I was already gone.
# Synthesizing sentence 264: I passed under Lillian a second time, peeking up her skirt a second time, more to needle her than out of any lingering curiosity.
# Synthesizing sentence 265: The big door was, as it turned out, locked, and I wasn’t able to bypass the big padlock any more than I could bypass the latch of the window above.
# Synthesizing sentence 266: But the door rolled on wheels, and the wheels fit in ruts, a long, shallow channel.
# Synthesizing sentence 267: I headed to the end of the door opposite the lock, and I pushed the full weight of my body against it.
# Synthesizing sentence 268: The lock rattled, heavy.
# Synthesizing sentence 269: I tried a bit more pressure, pushing, and the door tilted, the bottom corner closest to me rising out of the channel.
# Synthesizing sentence 270: Gripping the door, I lifted it up and away, wood scraping concrete as I created a triangular gap.
# Synthesizing sentence 271: I slipped inside, my eyes immediately going to the hayloft, the upper floor.
# Synthesizing sentence 272: Helen was there, sitting with one foot propped up, both hands in her lap to keep her skirt pressed down.
# Synthesizing sentence 273: Her face was still expressionless.
# Synthesizing sentence 274: Half of her attention was on me.
# Synthesizing sentence 275: Half was on the creature.
# Synthesizing sentence 276: There was a rain barrel beside her, rigged so it hung over the edge of the hayloft, collecting the water that ran in through the makeshift gutter, feeding a steady stream down into containers below.
# Synthesizing sentence 277: Runoff from those containers fed into the corner of the building.
# Synthesizing sentence 278: A drain from when the building had been a warehouse, keeping the goods dry.
# Synthesizing sentence 279: I studied the papers on the desk.
# Synthesizing sentence 280: Water from one of the windows above spat down.
# Synthesizing sentence 281: Barely large enough to qualify as drops, but they dotted one paper, making ink bleed.
# Synthesizing sentence 282: Sketches of the beast.
# Synthesizing sentence 283: Notations on structure and anatomy.
# Synthesizing sentence 284: One of the texts on a table beside the desk was hand-made.
# Synthesizing sentence 285: Pages had holes in them, and a cord was laced through, tying them to the heavy leather cover.
# Synthesizing sentence 286: With care, I paged through the thing.
# Synthesizing sentence 287: One being, knit together from several.
# Synthesizing sentence 288: The better traits of each, all drawn together.
# Synthesizing sentence 289: References to Wollstone’s texts, to the ratios of life, and to the volumes of genetic code for Felidae and Eunectes Murinus.
# Synthesizing sentence 290: A whole chapter on digestive enzymes.
# Synthesizing sentence 291: Diagrams of the thing’s fangs, which I had glimpsed as it devoured the mother cat, with labels for the reservoirs of venom that wasn’t true venom.
# Synthesizing sentence 292: It was enzymes, much like the ones bugs used to dissolve their meals before supping them.
# Synthesizing sentence 293: Notes suggested that the feature helped with the digestion of any and all food.
# Synthesizing sentence 294: Little doubt of what this thing had been engineered for.
# Synthesizing sentence 295: My finger traced the labels of glass containers, bottles and vials.
# Synthesizing sentence 296: Blood, bile, cerebral fluid…
#
# Venom.
# Synthesizing sentence 297: I’d expected it to be green, but it was clear, in a glass container with a murky exterior, about as tall and wide as a wine bottle, though more cylindrical.
# Synthesizing sentence 298: There was a noise at the door, and I took a long step to the side, toward the shadows beside one of the big wooden containers for water.
# Synthesizing sentence 299: Only Lillian, followed by Gordon, passing through the gap.
# Synthesizing sentence 300: Gordon was the largest of us, and it was a particularly tight fit for him.
# Synthesizing sentence 301: I continued paging through the text.
# Synthesizing sentence 302: Diet.
# Synthesizing sentence 303: My eye traveled down the list.
# Synthesizing sentence 304: Meal times, meal sources, meal sizes.
# Synthesizing sentence 305: Pig carcass.
# Synthesizing sentence 306: Dog carcass.
# Synthesizing sentence 307: Pig carcass.
# Synthesizing sentence 308: Scavenged meal, unknown type.
# Synthesizing sentence 309: Pig carcass.
# Synthesizing sentence 310: Pig carcass.
# Synthesizing sentence 311: Scavenged meal, dog.
# Synthesizing sentence 312: It wasn’t fully grown, but it was close, and it grew fast.
# Synthesizing sentence 313: Two meals a week.
# Synthesizing sentence 314: I recalled that it had eaten the cat, and then looked back at the entries.
# Synthesizing sentence 315: Forty pounds, sixty pounds, forty pounds, est.
# Synthesizing sentence 316: one hundred pounds…  I noted the numbers, and tried to find the pattern between those numbers and the meals.
# Synthesizing sentence 317: I moved ahead a few pages until I reached the first partial page.
# Synthesizing sentence 318: Room left for more entries.
# Synthesizing sentence 319: Last meal, just over two days ago, goat carcass.
# Synthesizing sentence 320: It was hungry already.
# Synthesizing sentence 321: Quite possibly getting ready for one last growth spurt.
# Synthesizing sentence 322: The more recent meals were larger.
# Synthesizing sentence 323: Gordon was crouched, peering at labels on bottles.
# Synthesizing sentence 324: He saw me looking, and tapped his nose, then pointed at the bottles
#
# I nodded.
# Synthesizing sentence 325: I tapped the book, getting his attention, and stepped away while he read the entries.
# Synthesizing sentence 326: He didn’t have much of a chance to read.
# Synthesizing sentence 327: There was a sound outside, violent, of things falling over.
# Synthesizing sentence 328: Chaos.
# Synthesizing sentence 329: I could picture Jamie’s hiding spot, the way the door had been propped up.
# Synthesizing sentence 330: This was a warning.
# Synthesizing sentence 331: “Hide,” Gordon whispered.
# Synthesizing sentence 332: You don’t have to tell me, I thought, but I held my tongue.
# Synthesizing sentence 333: Very carefully, I closed the book.
# Synthesizing sentence 334: I shifted the angle to return it to the position it had been in.
# Synthesizing sentence 335: My eye swept over the room.
# Synthesizing sentence 336: Water on the floor.
# Synthesizing sentence 337: Did it matter?
# Synthesizing sentence 338: No.
# Synthesizing sentence 339: There was no time, besides.
# Synthesizing sentence 340: I slipped into the shadowy crevice between the water tank and the wall.
# Synthesizing sentence 341: Gordon and Lillian were already gone.
# Synthesizing sentence 342: Helen, who had been above, watching everything, was now gone.
# Synthesizing sentence 343: No doubt hiding behind the water barrel, a step away from where she had been.
# Synthesizing sentence 344: Four seconds passed before I heard the lock rattle.
# Synthesizing sentence 345: The door’s wheel slammed back down into the rut as it was pulled to one side, but there was no sign of concern or suspicion.
# Synthesizing sentence 346: He closed the door behind him, and the sound of something being dragged joined the sound of hard shoe soles on the wooden floor, marking his progress across his makeshift laboratory.
# Synthesizing sentence 347: “Damned beast,” he muttered.
# Synthesizing sentence 348: “Where are you?”
#
# He made seemingly deliberate noise as he cleared a table, then dropped his burden on top of it.
# Synthesizing sentence 349: I heard a grunt, his, and the smell of blood filled the air.
# Synthesizing sentence 350: The amount of light in the room shifted.
# Synthesizing sentence 351: I judged it to be the beast’s bulk blocking the light from the windows above.
# Synthesizing sentence 352: “There you are,” he said.
# Synthesizing sentence 353: With swift strides, he crossed to the water tank I crouched beside.
# Synthesizing sentence 354: He wasted no time in dipping his hands inside, splashing water as he swished his hands inside.
# Synthesizing sentence 355: Some of the water that slopped around the top of the tank splashed down on top of me.
# Synthesizing sentence 356: I was close enough to touch him.
# Synthesizing sentence 357: There was a scuffle and a thud as the cat-snake creature touched ground, eager to get to its meal.
# Synthesizing sentence 358: Its creator was already at the desk, picking select vials, dabbing a bit on his wrist, then rubbing his wrists together.
# Synthesizing sentence 359: I thought of Gordon’s gesture.
# Synthesizing sentence 360: Touching his nose.
# Synthesizing sentence 361: Scents?
# Synthesizing sentence 362: Pheromones.
# Synthesizing sentence 363: It was how he controlled the beast he had made.
# Synthesizing sentence 364: I could see him as he tidied papers, only periodically glancing over his shoulder.
# Synthesizing sentence 365: He hummed.
# Synthesizing sentence 366: But for some stubble on his chin, he looked like a gentleman, with a four-button vest under a butcher’s apron and an ankle-length raincoat.
# Synthesizing sentence 367: His hair was sandy, parted to one side.
# Synthesizing sentence 368: I could see the creature raise its head.
# Synthesizing sentence 369: The meal was in its mouth, and it was angling its head to let it all slide down its gullet.
# Synthesizing sentence 370: Its creator used a pair of tongs to collect a bloody sack.
# Synthesizing sentence 371: I took it to be the sack the creature’s meal had been in.
# Synthesizing sentence 372: Another pig, perhaps.
# Synthesizing sentence 373: He disappeared from view.
# Synthesizing sentence 374: A rustle.
# Synthesizing sentence 375: Then the tongs clanged to the floor.
# Synthesizing sentence 376: The beast changed the angle of its head.
# Synthesizing sentence 377: “A child?” the man’s voice was touched with incredulity.
# Synthesizing sentence 378: There was a commotion, a scrape of steel on concrete as a foot dragged on the tongs.
# Synthesizing sentence 379: I remained where I was.
# Synthesizing sentence 380: The struggle continued, intermittent, as he backed up, the desk of papers to one side, the table of bottles to the other.
# Synthesizing sentence 381: He had a carving knife to Gordon’s throat.
# Synthesizing sentence 382: Presumably the same one he’d used to cut open the creature’s meal and get its attention.
# Synthesizing sentence 383: “Two of you.
# Synthesizing sentence 384: Are there more?”
#
# Gordon was silent.
# Synthesizing sentence 385: “I’m asking you!” the man was angry, outraged.
# Synthesizing sentence 386: “Are there more?
# Synthesizing sentence 387: Girl!
# Synthesizing sentence 388: How many?
# Synthesizing sentence 389: Tell me or I cut him!”
#
# “A few,” Lillian said.
# Synthesizing sentence 390: “Four.”
#
# “The noise outside.
# Synthesizing sentence 391: That was one?”
#
# “Five, if you count him,” she said, her voice small.
# Synthesizing sentence 392: “Do not play games with me!” the man roared.
# Synthesizing sentence 393: “Show yourselves!
# Synthesizing sentence 394: Each of you!”
#
# I exhaled slowly.
# Synthesizing sentence 395: I stepped out of the gap by the water tank.
# Synthesizing sentence 396: Helen was above, at the hayloft.
# Synthesizing sentence 397: Standing by the edge.
# Synthesizing sentence 398: Lillian was closer to the door.
# Synthesizing sentence 399: She and Gordon had been hiding in or near a garbage bin.
# Synthesizing sentence 400: The beast was relaxed, having just eaten its fill.
# Synthesizing sentence 401: “Children?” the man sounded incredulous.
# Synthesizing sentence 402: He wasn’t wrong.
# Synthesizing sentence 403: At thirteen, Lillian was the oldest of us.
# Synthesizing sentence 404: Gordon was only twelve as of last month.
# Synthesizing sentence 405: “Yeah,” Gordon said, his voice strained.
# Synthesizing sentence 406: The man had his throat caught in the crook of one arm, exposing his lower throat.
# Synthesizing sentence 407: “An infestation,” the man said.
# Synthesizing sentence 408: “My experiment didn’t root you out?”
#
# His eye traveled over each of us in turn.
# Synthesizing sentence 409: I saw the faintest crease appear between his eyebrows.
# Synthesizing sentence 410: He seemed to come to a realization.
# Synthesizing sentence 411: “You’ve covered yourself in something.
# Synthesizing sentence 412: So it can’t smell you.
# Synthesizing sentence 413: This was premeditated.”
#
# I met Lillian’s eyes.
# Synthesizing sentence 414: I jerked my chin.
# Synthesizing sentence 415: Pointed at her with my hand.
# Synthesizing sentence 416: The easy, natural interactions and cooperation that followed from years of working together weren’t there with Lil.
# Synthesizing sentence 417: She was new.
# Synthesizing sentence 418: A recent addition to the group.
# Synthesizing sentence 419: I almost thought she got the wrong idea, until she opened her mouth.
# Synthesizing sentence 420: “Yes,” she said.
# Synthesizing sentence 421: “We… heard about you.”
#
# “Heard what?”
#
# “That there was something loose in the slums.
# Synthesizing sentence 422: It was eating pets.
# Synthesizing sentence 423: It ate a man that was sleeping outside.”
#
# “No,” the man said.
# Synthesizing sentence 424: “Yes,” Lillian said.
# Synthesizing sentence 425: “There are witnesses.”
#
# “The witnesses are wrong,” the man said.
# Synthesizing sentence 426: “You let it go out to find its own food,” Gordon said, his voice still strangled.
# Synthesizing sentence 427: “You couldn’t afford to keep it fed as it grew this large.
# Synthesizing sentence 428: You let it feed on strays.
# Synthesizing sentence 429: Which it did.
# Synthesizing sentence 430: Except one of those strays was human.
# Synthesizing sentence 431: It’s in the book.
# Synthesizing sentence 432: Meal, unknown type.”
#
# I edged around behind the man.
# Synthesizing sentence 433: “You don’t know what you’re talking about.
# Synthesizing sentence 434: I’ve studied its leavings,” the man said, ignoring the label.
# Synthesizing sentence 435: “Nothing human.”
#
# “Nothing conclusively human, you mean,” Gordon said.
# Synthesizing sentence 436: “But you aren’t able to identify all of what it ate.”
#
# “You!”  The man raised his voice.
# Synthesizing sentence 437: He sounded more emotional than before.
# Synthesizing sentence 438: “Up there!
# Synthesizing sentence 439: Girl!
# Synthesizing sentence 440: Stay put.”
#
# Helen froze where she was.
# Synthesizing sentence 441: “You’re a killer,” Gordon said, more insistent.
# Synthesizing sentence 442: “We were calling you the snake charmer.”
#
# I edged closer to the table.
# Synthesizing sentence 443: I didn’t make a sound, but the snake charmer sensed trouble before it arrived.
# Synthesizing sentence 444: He wheeled on me, the knife dangerously close to Gordon’s throat.
# Synthesizing sentence 445: I lunged in the same movement, seizing the big bottle.
# Synthesizing sentence 446: The venom.
# Synthesizing sentence 447: I held it high.
# Synthesizing sentence 448: “You don’t care what happens to him?” the snake charmer asked.
# Synthesizing sentence 449: “I care,” I said.
# Synthesizing sentence 450: “That’s why, if you cut him, and if it looks like he isn’t going to be okay, I’m going to throw this at the both of you.”
#
# The snake charmer’s eyes darted around.
# Synthesizing sentence 451: He couldn’t watch all of us at once.
# Synthesizing sentence 452: “Move!” he said.
# Synthesizing sentence 453: “Go around.
# Synthesizing sentence 454: I want you as a group.”
#
# I didn’t budge.
# Synthesizing sentence 455: “Move!”
#
# “No,” I said.
# Synthesizing sentence 456: “It’s over, snake charmer,” Gordon said.
# Synthesizing sentence 457: “That is not my name!”
#
# “It’s a name they’ll give you,” Gordon said.
# Synthesizing sentence 458: “They’ll make you a monster.
# Synthesizing sentence 459: It’s what the Academy does.
# Synthesizing sentence 460: Dehumanizes the dangerous ones.
# Synthesizing sentence 461: You can’t get all of us, not with the way things are, here.
# Synthesizing sentence 462: Some are bound to escape.
# Synthesizing sentence 463: They’ll tell people, and those people will find you.
# Synthesizing sentence 464: You know the resources the Academy has.”
#
# “No,” the snake charmer said.
# Synthesizing sentence 465: “You don’t know?” Gordon asked.
# Synthesizing sentence 466: “This is not my fault,” the snake charmer said.
# Synthesizing sentence 467: “The Academy… this rests on their shoulders, not mine.
# Synthesizing sentence 468: You can’t enroll without showing your skill, and you can’t show your skill without experimenting, but oh, no, they don’t allow that, do they?”
#
# “There are ways,” Lillian said.
# Synthesizing sentence 469: “No!” the man barked, “No!
# Synthesizing sentence 470: Not nearly enough.
# Synthesizing sentence 471: The world is changing, and they’re deciding the course.
# Synthesizing sentence 472: They’re putting us in this situation, where risks have to be taken.
# Synthesizing sentence 473: Gambles have to be made, or history will continue to be made, names attached to great discoveries, and the rest of us?
# Synthesizing sentence 474: If we’re lucky, we get left by the wayside.
# Synthesizing sentence 475: If we’re not, we’re just fuel for what they’re setting in motion.”
#
# “I’m a student there,” Lillian said.
# Synthesizing sentence 476: “I just started, but… I’m enrolled.
# Synthesizing sentence 477: First year of study.
# Synthesizing sentence 478: Not them.
# Synthesizing sentence 479: Just me.”
#
# I could see the man’s expression twist.
# Synthesizing sentence 480: Incomprehension.
# Synthesizing sentence 481: Comprehension, which was almost worse.
# Synthesizing sentence 482: Hatred for a thirteen year old girl.
# Synthesizing sentence 483: Then rage, not a clean, pure kind, but one that only drove him further into a corner.
# Synthesizing sentence 484: His hand tightened on the grip of the knife.
# Synthesizing sentence 485: I figured out the destination he was arriving at before he did.
# Synthesizing sentence 486: I arrived at my own, and I mustered up some courage.
# Synthesizing sentence 487: Very deliberately, I grunted, heaving the bottle of acid at the snake charmer.
# Synthesizing sentence 488: He heard the grunt, but so did Gordon.
# Synthesizing sentence 489: With the snake charmer’s attention caught between Lillian and me, Gordon found a chance to protect his throat, keeping the knife from cutting.
# Synthesizing sentence 490: The bottle flew lazily through the air.
# Synthesizing sentence 491: Gordon ducked, head down, and the snake charmer released him.
# Synthesizing sentence 492: The man caught the bottle in a bear hug.
# Synthesizing sentence 493: He stared down at the container.
# Synthesizing sentence 494: All the same emotions he’d felt for Lillian, now aimed at me, progressing much faster this time.
# Synthesizing sentence 495: Incomprehension, comprehension, hatred, rage.
# Synthesizing sentence 496: Directed at me.
# Synthesizing sentence 497: I backed away, stumbling, falling.
# Synthesizing sentence 498: I covered my face as he swung, using the waterproof cloth to try and shield my body.
# Synthesizing sentence 499: He didn’t throw at me, but at the floor.
# Synthesizing sentence 500: The chance of me catching it was small, but by throwing it at the floor, he could guarantee that the bottle would shatter into a spray I couldn’t possibly shield all of myself from.
# Synthesizing sentence 501: The pain was sharp, at first, droplets touching skin, immediately breaking it down.
# Synthesizing sentence 502: Then it burned.
# Synthesizing sentence 503: The horrible coldness was worse, because it suggested dying nerves.
# Synthesizing sentence 504: All down my arms, and one side of my face.
# Synthesizing sentence 505: I screamed.
# Synthesizing sentence 506: The creature turned its head, but didn’t move.
# Synthesizing sentence 507: The man turned, wheeling on the others.
# Synthesizing sentence 508: Gordon was ready, already closing in, taking advantage of the short moment it took the snake charmer to adjust his grip on the knife, so soon after heaving the bottle.
# Synthesizing sentence 509: A tackle, shoulder into the man’s gut, taking advantage of smaller size and a good physique.
# Synthesizing sentence 510: Gordon drove the man back.
# Synthesizing sentence 511: Gordon was the hero, golden haired, noble, likeable.
# Synthesizing sentence 512: Talented.
# Synthesizing sentence 513: When he broke away, letting the snake charmer stumble back two steps, recovering balance, Gordon had the knife in hand.
# Synthesizing sentence 514: The beast rose to its feet.
# Synthesizing sentence 515: Sniffing.
# Synthesizing sentence 516: I managed to stop screaming, going as still as possible.
# Synthesizing sentence 517: It still edged closer to me.
# Synthesizing sentence 518: Interested.
# Synthesizing sentence 519: Still hungry,  I noted.
# Synthesizing sentence 520: Helen acted.
# Synthesizing sentence 521: Tipping over the barrel.
# Synthesizing sentence 522: Drenching the snake charmer, washing away his charm, the pheromones.
# Synthesizing sentence 523: “Brats!” the snake charmer spat the word.
# Synthesizing sentence 524: “You little shits!
# Synthesizing sentence 525: You think you have control of this situation?”
#
# “Your experiment is trying to decide between you and Sylvester over there,” Gordon said.
# Synthesizing sentence 526: “You smell, he’s bleeding.
# Synthesizing sentence 527: Both are tempting.”
#
# The snake charmer made an incoherent noise.
# Synthesizing sentence 528: “Thing is, if you start bleeding…” Gordon said, trailing off.
# Synthesizing sentence 529: “You’ll suddenly be a lot more tempting.”
#
# “Try it,” the snake charmer said.
# Synthesizing sentence 530: Gordon did.
# Synthesizing sentence 531: He approached, and the snake charmer tried to grab him.
# Synthesizing sentence 532: The man’s hands only grabbed clothes.
# Synthesizing sentence 533: A hood and cloak meant to keep the rain off.
# Synthesizing sentence 534: Gordon let him, and ducked low, the clothing bunching up around his neck and upper chest.
# Synthesizing sentence 535: Gordon sliced the snake charmer’s stomach.
# Synthesizing sentence 536: A shallow cut.
# Synthesizing sentence 537: Another grab, wrestling Gordon, trying to overpower with strength, seizing one arm.
# Synthesizing sentence 538: Gordon let the knife drop out of one hand, falling into the palm of another.
# Synthesizing sentence 539: He cut the back of the man’s left knee.
# Synthesizing sentence 540: When the man fell, screaming, Gordon cut the other knee.
# Synthesizing sentence 541: He skipped back as the snake charmer fell.
# Synthesizing sentence 542: The snake stirred, its attention no longer predominantly on me.
# Synthesizing sentence 543: I could see the snake charmer realizing the same thing I had minutes ago.
# Synthesizing sentence 544: He knew his experiment.
# Synthesizing sentence 545: He knew how it hunted.
# Synthesizing sentence 546: It scavenged, sniffing out prey.
# Synthesizing sentence 547: Blind, it reacted to noise and smell.
# Synthesizing sentence 548: Minimizing the noise one made was vital.
# Synthesizing sentence 549: Given the situation, however, staying silent spelled the man’s doom.
# Synthesizing sentence 550: Already, his creation was sniffing him out.
# Synthesizing sentence 551: He smelled of blood.
# Synthesizing sentence 552: “Pheromones,” he said, knowing how dangerous it was to speak, that every sound helped him lose the tug of war that let the creature decide between devouring him and devouring me.
# Synthesizing sentence 553: “Let me- I’ll come with you.
# Synthesizing sentence 554: You can take me in.
# Synthesizing sentence 555: You win.”
#
# Nobody moved or responded.
# Synthesizing sentence 556: He used his arms to pull himself forward, progressing toward the table.
# Synthesizing sentence 557: Each motion drew more attention from his beast.
# Synthesizing sentence 558: Foot by foot, he closed on the table, and each sound was akin to a fisherman’s line, reeling in the beast.
# Synthesizing sentence 559: He reached the table, struggling, and he raised himself up, using one hand to drag a leg forward, propping it under him.
# Synthesizing sentence 560: Reaching across the table-
#
# Gordon kicked the leg of the table, hard.
# Synthesizing sentence 561: The table shifted a foot, and the snake charmer collapsed.
# Synthesizing sentence 562: “No.
# Synthesizing sentence 563: Please.”
#
# The snake charmer looked at us.
# Synthesizing sentence 564: At Gordon, then Helen, who loomed above, perched on the hayloft.
# Synthesizing sentence 565: At me, as I glared at him, my face burned.
# Synthesizing sentence 566: At Lillian, who was sitting in the corner, hands over her head.
# Synthesizing sentence 567: Who was not one of us.
# Synthesizing sentence 568: “Please,” he said.
# Synthesizing sentence 569: “Not like this.”
#
# Helen’s expression didn’t change.
# Synthesizing sentence 570: Gordon shifted his position, placing himself between the snake charmer and the table, arms folded.
# Synthesizing sentence 571: I remained where I was, limp and breathing hard.
# Synthesizing sentence 572: I could see it dawn on the man.
# Synthesizing sentence 573: Comprehension settling in as he realized what he was dealing with.
# Synthesizing sentence 574: The snake seized the man’s feet, and began the very slow process of swallowing him.
# Synthesizing sentence 575: The snake charmer’s screams became frantic.
# Synthesizing sentence 576: “Lillian,” Gordon said, raising his voice to be heard over the screams.
# Synthesizing sentence 577: “I don’t want to see.”
#
# “Then shield your eyes.
# Synthesizing sentence 578: But your job is to keep us in one piece.
# Synthesizing sentence 579: Sly is hurt.
# Synthesizing sentence 580: Focus, and make sure he doesn’t die.”
#
# I felt the burning stop as Lillian tended to me.
# Synthesizing sentence 581: By the time she was done, the screams had stopped.
# Synthesizing sentence 582: The powder that dusted me made it hard to see, but that was fine.
# Synthesizing sentence 583: I was lifted to my feet.
# Synthesizing sentence 584: “I have to say, I’m very interested in what the fuck you were doing, faking that fall, setting yourself up to get hurt just now,” Gordon said.
# Synthesizing sentence 585: “You’ll have to tell me later, when you can talk again.”
#
# I managed a nod.
# Synthesizing sentence 586: “Off we go,” he said.
# Synthesizing sentence 587: I could hear the door open.
# Synthesizing sentence 588: Helen spoke for the first time in a while.
# Synthesizing sentence 589: Her voice was cute.
# Synthesizing sentence 590: “The Academy sends its regards, Mr. Snake Charmer.”

# %% [markdown]
# ## Listen to the Complete Reading of Chapter 1

# %%
from IPython.display import display, Audio
display(Audio(data=audio_waveform, rate=24000, autoplay=False))

# %% [markdown]
# ## Lets try the rest of the "Taking Root" section after this chapter

# %%
from One_Taking_Root import produce_taking_root
taking_root = produce_taking_root()

# %%
len(taking_root)
# Out:
# 12

# %%
for i, section in enumerate(taking_root):
    if i < 11:
        print(f'Synthesizing Part 1.{i+2}')
    elif i == 11:
        print('Synthesizing Enemy Chapter 1')
    sentences = sent_tokenize(section)

    # Initialize an empty list to collect sentence audio waveforms
    sentence_audio_waveforms = []
    
    # Iterate over each sentence and synthesize audio
    for sentence in sentences:
    
        # Synthesize audio for the current sentence
        chunks = model.inference_stream(sentence, "en", gpt_cond_latent, speaker_embedding)
    
        # Collect all audio chunks for the current sentence
        sentence_audio_chunks = []
        for chunk in chunks:
            audio_numpy = chunk.squeeze().numpy()
            sentence_audio_chunks.append(audio_numpy)
    
        # Concatenate all audio chunks into a single waveform for the sentence
        sentence_audio_waveform = np.concatenate(sentence_audio_chunks)
    
        # Append the sentence audio waveform to the list of sentence waveforms
        sentence_audio_waveforms.append(sentence_audio_waveform)
    
    # Concatenate all sentence audio waveforms into a single continuous waveform
    audio_waveform = np.concatenate(sentence_audio_waveforms)

    display(Audio(data=audio_waveform, rate=24000, autoplay=False))
